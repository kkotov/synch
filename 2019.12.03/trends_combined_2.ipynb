# %% [markdown]
# # Prepare data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# Load data
train_df = pd.read_csv("../sales_train.csv.gz")
test_df  = pd.read_csv("../test.csv.gz")

categories = pd.read_csv('../item_categories.csv')
items = pd.read_csv('../items.csv')
shops = pd.read_csv('../shops.csv')

# %%
# %store -r __prepare_data_4

# %%
# %%time
__prepare_data_4
# Out:
# CPU times: user 3min, sys: 1min 44s, total: 4min 45s
# Wall time: 4min 53s

# %%
# aggregate daily sales to monthly sales
monthly = train_df.groupby(["item_id","shop_id","date_block_num"]).item_cnt_day.sum()
monthly = monthly.reset_index()
monthly.columns = ["item_id","shop_id","date_block_num","target"]

# this is still zero-suppressed data frame
monthly.head()
# Out:
#    item_id  shop_id  date_block_num  target
# 0        0       54              20     1.0
# 1        1       55              15     2.0
# 2        1       55              18     1.0
# 3        1       55              19     1.0
# 4        1       55              20     1.0

# %% [markdown]
# # Explore sales
# * find how many items didn't sell last 1, 2, and 3 months (discontinued items)
# * find how many stores didn't sell anything last 1, 2, and 3 month (closed stores)
# * find how many items were selling throught at lease one year
# * find how many stores were open through at least one year
# * check intersections

# %% [markdown]
# ## Explore shop sales
#
# prepare data for shops and for items in one go below

# %%
# unique shops, items, and dates
shops = pd.DataFrame({'shop_id': monthly.shop_id.unique()}).sort_values(by=['shop_id'])
items = pd.DataFrame({'item_id': monthly.item_id.unique()}).sort_values(by=['item_id'])
dates = pd.DataFrame({'date_block_num': range(35)}) # month #34 will be our prediction target
# trick to get an outer join in pandas
shops['dup_key'] = 1
items['dup_key'] = 1
dates['dup_key'] = 1

# create combinations of all shops and dates as well as combinations of all items and dates
scaffold_s = pd.merge(shops, dates, how='outer', on=['dup_key'])[['shop_id','date_block_num']]
scaffold_i = pd.merge(items, dates, how='outer', on=['dup_key'])[['item_id','date_block_num']]

# trade zero suppression for NaNs at dates with no sales, aggregate sales per shop or item
gapless_shops = pd.merge(scaffold_s,
                         (monthly                         
                          .groupby(['shop_id','date_block_num'])
                          .agg({'target': [sum,len,np.mean],
                                'item_id':lambda x: len(x.unique())}) # important to calculate this before the scaffold
                          .reset_index()),
                         how='left',
                         on=['shop_id','date_block_num'])

gapless_items = pd.merge(scaffold_i,
                         (monthly
                          .groupby(['item_id','date_block_num'])
                          .agg({'target': [sum,len,np.mean],
                                'shop_id':lambda x: len(x.unique())}) # also makes sense to average over open shops only
                          .reset_index()),
                         how='left',
                         on=['item_id','date_block_num'])

gapless_shops.columns = ['shop_id', 'date_block_num', 'target_sum', 'target_len', 'target_mean', 'n_items']
gapless_items.columns = ['item_id', 'date_block_num', 'target_sum', 'target_len', 'target_mean', 'n_shops']
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py:3947: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   new_axis = axis.drop(labels, errors=errors)

# %%
# construct operators (matricies) that, applied to a time series, yield their lags:
#   1) create and flatten a unit matrix
current = np.identity(35).reshape(-1)
#   2) shift left by one, two, and tree positions, zero-pad on the right and zero-out top rows
lag1 = np.concatenate(([0]*35,  current[36:], [0])).reshape(-1,35)
lag2 = np.concatenate(([0]*70,  current[72:], [0]*2)).reshape(-1,35)
lag3 = np.concatenate(([0]*105, current[108:],[0]*3)).reshape(-1,35)


def construct_lags2(sales, cols):
    """
    sales - two dimensional data frame
    """
    sales_lag1 = pd.DataFrame(np.dot(lag1, sales.values), columns=cols)
    sales_lag2 = pd.DataFrame(np.dot(lag2, sales.values), columns=cols)
    sales_lag3 = pd.DataFrame(np.dot(lag3, sales.values), columns=cols)

    no_sales = (sales_lag1 + sales_lag2 + sales_lag3 < 1).stack().reset_index()
    no_sales.columns = ['date_block_num', sales.columns.name, 'no_sales']

    lags = pd.concat([sales_lag1.stack(), sales_lag2.stack(), sales_lag3.stack()], axis=1)
    lags.reset_index(inplace=True)
    lags.columns = ['date_block_num', sales.columns.name, 'lag1', 'lag2', 'lag3']
    return pd.merge(no_sales, lags, how='left', on=['date_block_num', sales.columns.name])

# %%
# pivot the "melted" table into [date,shop] sales matrix and find shops closed within 3 consequetive lags
sales_shops = gapless_shops.pivot(columns='shop_id', values='target_sum', index='date_block_num')
no_sales_shops = construct_lags2(sales_shops.fillna(0), sorted(sales_shops.columns.unique().tolist()))['no_sales']

gapless_shops['target_ave'] = gapless_shops['target_sum']/gapless_shops['n_items']

ave_sales_shops = (gapless_shops
                   .pivot(columns='shop_id', values='target_ave', index='date_block_num')
                   .fillna(0))

stock_shops = (gapless_shops
               .pivot(columns='shop_id', values='n_items', index='date_block_num')
               .fillna(0))

lagged_sales_shops = construct_lags2(ave_sales_shops, sorted(ave_sales_shops.columns.unique().tolist()))
lagged_stock_shops = construct_lags2(stock_shops, sorted(stock_shops.columns.unique().tolist()))

lagged_sales_shops['no_sales'] = no_sales_shops
lagged_sales_shops['stock_lag1'] = lagged_stock_shops["lag1"]
lagged_sales_shops['stock_lag2'] = lagged_stock_shops["lag2"]
lagged_sales_shops['stock_lag3'] = lagged_stock_shops["lag3"]

lagged_sales_shops.sort_values(by=['shop_id','date_block_num']).head()
# Out:
#      date_block_num  shop_id  no_sales      lag1      lag2      lag3  \
# 0                 0        0      True  0.000000  0.000000  0.000000
# 60                1        0     False  2.338784  0.000000  0.000000
# 120               2        0     False  2.515189  2.338784  0.000000
# 180               3        0     False  0.000000  2.515189  2.338784
# 240               4        0     False  0.000000  0.000000  2.515189
#
#      stock_lag1  stock_lag2  stock_lag3
# 0           0.0         0.0         0.0
# 60       2385.0         0.0         0.0
# 120      2436.0      2385.0         0.0
# 180         0.0      2436.0      2385.0
# 240         0.0         0.0      2436.0

# %%
qwe = (pd.merge(lagged_sales_shops, all_data, how='inner', on=['date_block_num', 'shop_id'])
       .groupby(['date_block_num','shop_id'])
       .agg({'total_monthly_shop_sales_lag_1': lambda x: np.NA if x.empty else x.iloc[0],
             'lag1':                           lambda x: np.NA if x.empty else x.iloc[0],
             'stock_lag1':                     lambda x: np.NA if x.empty else x.iloc[0]}))

# %%
qwe.tail()
# Out:
#                         total_monthly_shop_sales_lag_1      lag1  stock_lag1
# date_block_num shop_id
# 34             55                             0.299280  4.195745       470.0
#                56                             0.220580  1.574813       802.0
#                57                             0.411047  1.904605      1216.0
#                58                             0.257343  1.798507       804.0
#                59                             0.145760  1.580000       500.0

# %%
all_data[all_data.date_block_num==33].groupby(["date_block_num", "shop_id"]).target.sum().tail()
# Out:
# date_block_num  shop_id
# 33              55         1620.0
#                 56         1194.0
#                 57         2225.0
#                 58         1393.0
#                 59          789.0
# Name: target, dtype: float64

# %%
all_data[all_data.date_block_num==33].groupby(["date_block_num", "shop_id"]).target.size().head()
# Out:
# date_block_num  shop_id
# 33              2          5413
#                 3          5413
#                 4          5413
#                 5          5413
#                 6          5413
# Name: target, dtype: int64

# %%
print(len(items))
print(len(all_data[all_data.date_block_num==3].item_id.unique()))
gapless_shops[gapless_shops.date_block_num==33].tail()#['n_items']
# Out:
# 21807
# 8145
#       shop_id  date_block_num  target_sum  target_len  target_mean  n_items  \
# 1958       55              33      1972.0       470.0     4.195745    470.0
# 1993       56              33      1263.0       802.0     1.574813    802.0
# 2028       57              33      2316.0      1216.0     1.904605   1216.0
# 2063       58              33      1446.0       804.0     1.798507    804.0
# 2098       59              33       790.0       500.0     1.580000    500.0
#
#       target_ave
# 1958    4.195745
# 1993    1.574813
# 2028    1.904605
# 2063    1.798507
# 2098    1.580000

# %%
gapless_shops[gapless_shops.date_block_num==33].tail() # unclipped
# Out:
#       shop_id  date_block_num  target_sum  target_len  target_mean  n_items  \
# 1958       55              33      1972.0       470.0     4.195745    470.0
# 1993       56              33      1263.0       802.0     1.574813    802.0
# 2028       57              33      2316.0      1216.0     1.904605   1216.0
# 2063       58              33      1446.0       804.0     1.798507    804.0
# 2098       59              33       790.0       500.0     1.580000    500.0
#
#       target_ave
# 1958    4.195745
# 1993    1.574813
# 2028    1.904605
# 2063    1.798507
# 2098    1.580000

# %%
all_data = pd.merge(all_data, lagged_sales_shops, how='left', on=['date_block_num','shop_id'])

# %%
predictors2 = predictors + ["no_sales", "lag1", "lag2", "lag3", "stock_lag1", "stock_lag2", "stock_lag3"]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

train = all_data[(all_data.date_block_num>11)&(all_data.date_block_num<33)].fillna(0) # reduced traning set

X_train, X_test, y_train, y_test = \
    train_test_split(train[predictors2], train.target, test_size=0.2, random_state=123)

model = RandomForestRegressor(n_estimators=64, max_features=6, n_jobs=6) #len(predictors)/2
model.fit(X_train, y_train)

ypred = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, ypred))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 0.802854

# %%
# %%time
from xgboost import XGBRegressor

xgmodel = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

xgmodel.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, y_train), (X_test, y_test)], 
    verbose=True, 
    early_stopping_rounds = 10)
# Out:
# /usr/local/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /usr/local/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [08:03:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [08:03:03] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	validation_0-rmse:1.12813	validation_1-rmse:1.15951
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.09295	validation_1-rmse:1.11244
# [2]	validation_0-rmse:1.0634	validation_1-rmse:1.07527
# [3]	validation_0-rmse:1.02751	validation_1-rmse:1.0456
# [4]	validation_0-rmse:0.998912	validation_1-rmse:1.01949
# [5]	validation_0-rmse:0.97803	validation_1-rmse:0.996824
# [6]	validation_0-rmse:0.960078	validation_1-rmse:0.976954
# [7]	validation_0-rmse:0.943892	validation_1-rmse:0.960623
# [8]	validation_0-rmse:0.930542	validation_1-rmse:0.947286
# [9]	validation_0-rmse:0.920226	validation_1-rmse:0.936647
# [10]	validation_0-rmse:0.910699	validation_1-rmse:0.925162
# [11]	validation_0-rmse:0.90308	validation_1-rmse:0.915944
# [12]	validation_0-rmse:0.896755	validation_1-rmse:0.908184
# [13]	validation_0-rmse:0.892154	validation_1-rmse:0.902272
# [14]	validation_0-rmse:0.886876	validation_1-rmse:0.896129
# [15]	validation_0-rmse:0.881966	validation_1-rmse:0.890158
# [16]	validation_0-rmse:0.878244	validation_1-rmse:0.885605
# [17]	validation_0-rmse:0.875319	validation_1-rmse:0.882155
# [18]	validation_0-rmse:0.872366	validation_1-rmse:0.878669
# [19]	validation_0-rmse:0.870138	validation_1-rmse:0.87591
# [20]	validation_0-rmse:0.866765	validation_1-rmse:0.872125
# [21]	validation_0-rmse:0.864527	validation_1-rmse:0.869734
# [22]	validation_0-rmse:0.862528	validation_1-rmse:0.867429
# [23]	validation_0-rmse:0.860908	validation_1-rmse:0.865589
# [24]	validation_0-rmse:0.859475	validation_1-rmse:0.863931
# [25]	validation_0-rmse:0.857756	validation_1-rmse:0.862023
# [26]	validation_0-rmse:0.856672	validation_1-rmse:0.860807
# [27]	validation_0-rmse:0.855446	validation_1-rmse:0.859487
# [28]	validation_0-rmse:0.853774	validation_1-rmse:0.857607
# [29]	validation_0-rmse:0.852563	validation_1-rmse:0.856299
# [30]	validation_0-rmse:0.85147	validation_1-rmse:0.8551
# [31]	validation_0-rmse:0.850418	validation_1-rmse:0.854048
# [32]	validation_0-rmse:0.849632	validation_1-rmse:0.853137
# [33]	validation_0-rmse:0.848784	validation_1-rmse:0.85224
# [34]	validation_0-rmse:0.847241	validation_1-rmse:0.850597
# [35]	validation_0-rmse:0.846124	validation_1-rmse:0.84936
# [36]	validation_0-rmse:0.845051	validation_1-rmse:0.84826
# [37]	validation_0-rmse:0.844365	validation_1-rmse:0.847542
# [38]	validation_0-rmse:0.843545	validation_1-rmse:0.846642
# [39]	validation_0-rmse:0.842441	validation_1-rmse:0.845505
# [40]	validation_0-rmse:0.841775	validation_1-rmse:0.844781
# [41]	validation_0-rmse:0.841025	validation_1-rmse:0.843971
# [42]	validation_0-rmse:0.840072	validation_1-rmse:0.842979
# [43]	validation_0-rmse:0.839456	validation_1-rmse:0.84235
# [44]	validation_0-rmse:0.839055	validation_1-rmse:0.841952
# [45]	validation_0-rmse:0.838442	validation_1-rmse:0.841342
# [46]	validation_0-rmse:0.838219	validation_1-rmse:0.841117
# [47]	validation_0-rmse:0.837941	validation_1-rmse:0.840834
# [48]	validation_0-rmse:0.837352	validation_1-rmse:0.840221
# [49]	validation_0-rmse:0.836939	validation_1-rmse:0.839793
# [50]	validation_0-rmse:0.836282	validation_1-rmse:0.83914
# [51]	validation_0-rmse:0.835842	validation_1-rmse:0.83865
# [52]	validation_0-rmse:0.835422	validation_1-rmse:0.838135
# [53]	validation_0-rmse:0.835017	validation_1-rmse:0.837658
# [54]	validation_0-rmse:0.834354	validation_1-rmse:0.836944
# [55]	validation_0-rmse:0.833749	validation_1-rmse:0.836365
# [56]	validation_0-rmse:0.833474	validation_1-rmse:0.836059
# [57]	validation_0-rmse:0.833185	validation_1-rmse:0.83578
# [58]	validation_0-rmse:0.832891	validation_1-rmse:0.835428
# [59]	validation_0-rmse:0.832377	validation_1-rmse:0.834964
# [60]	validation_0-rmse:0.832155	validation_1-rmse:0.834744
# [61]	validation_0-rmse:0.831969	validation_1-rmse:0.834568
# [62]	validation_0-rmse:0.831761	validation_1-rmse:0.834348
# [63]	validation_0-rmse:0.831162	validation_1-rmse:0.833749
# [64]	validation_0-rmse:0.830629	validation_1-rmse:0.833203
# [65]	validation_0-rmse:0.830318	validation_1-rmse:0.832864
# [66]	validation_0-rmse:0.829482	validation_1-rmse:0.832034
# [67]	validation_0-rmse:0.829216	validation_1-rmse:0.831768
# [68]	validation_0-rmse:0.828213	validation_1-rmse:0.830663
# [69]	validation_0-rmse:0.82803	validation_1-rmse:0.830504
# [70]	validation_0-rmse:0.827845	validation_1-rmse:0.830328
# [71]	validation_0-rmse:0.827634	validation_1-rmse:0.830076
# [72]	validation_0-rmse:0.826954	validation_1-rmse:0.829363
# [73]	validation_0-rmse:0.826747	validation_1-rmse:0.829168
# [74]	validation_0-rmse:0.826445	validation_1-rmse:0.828902
# [75]	validation_0-rmse:0.826298	validation_1-rmse:0.828753
# [76]	validation_0-rmse:0.826178	validation_1-rmse:0.828616
# [77]	validation_0-rmse:0.825474	validation_1-rmse:0.827912
# [78]	validation_0-rmse:0.825238	validation_1-rmse:0.827679
# [79]	validation_0-rmse:0.82492	validation_1-rmse:0.827329
# [80]	validation_0-rmse:0.824574	validation_1-rmse:0.826989
# [81]	validation_0-rmse:0.824457	validation_1-rmse:0.826841
# [82]	validation_0-rmse:0.824241	validation_1-rmse:0.826634
# [83]	validation_0-rmse:0.823947	validation_1-rmse:0.826346
# [84]	validation_0-rmse:0.823588	validation_1-rmse:0.825928
# [85]	validation_0-rmse:0.82333	validation_1-rmse:0.825676
# [86]	validation_0-rmse:0.823083	validation_1-rmse:0.825424
# [87]	validation_0-rmse:0.822885	validation_1-rmse:0.825231
# [88]	validation_0-rmse:0.822643	validation_1-rmse:0.82497
# [89]	validation_0-rmse:0.822466	validation_1-rmse:0.8248
# [90]	validation_0-rmse:0.821349	validation_1-rmse:0.823768
# [91]	validation_0-rmse:0.821242	validation_1-rmse:0.823654
# [92]	validation_0-rmse:0.821112	validation_1-rmse:0.823534
# [93]	validation_0-rmse:0.820995	validation_1-rmse:0.823419
# [94]	validation_0-rmse:0.820693	validation_1-rmse:0.823108
# [95]	validation_0-rmse:0.820514	validation_1-rmse:0.822919
# [96]	validation_0-rmse:0.820318	validation_1-rmse:0.822698
# [97]	validation_0-rmse:0.820219	validation_1-rmse:0.822608
# [98]	validation_0-rmse:0.81956	validation_1-rmse:0.821932
# [99]	validation_0-rmse:0.819315	validation_1-rmse:0.821679
# [100]	validation_0-rmse:0.819027	validation_1-rmse:0.821394
# [101]	validation_0-rmse:0.818857	validation_1-rmse:0.821213
# [102]	validation_0-rmse:0.818733	validation_1-rmse:0.821109
# [103]	validation_0-rmse:0.818584	validation_1-rmse:0.820973
# [104]	validation_0-rmse:0.818488	validation_1-rmse:0.820883
# [105]	validation_0-rmse:0.818222	validation_1-rmse:0.820639
# [106]	validation_0-rmse:0.818	validation_1-rmse:0.820422
# [107]	validation_0-rmse:0.81774	validation_1-rmse:0.820159
# [108]	validation_0-rmse:0.817614	validation_1-rmse:0.820019
# [109]	validation_0-rmse:0.817412	validation_1-rmse:0.819828
# [110]	validation_0-rmse:0.817267	validation_1-rmse:0.819663
# [111]	validation_0-rmse:0.816445	validation_1-rmse:0.818807
# [112]	validation_0-rmse:0.816355	validation_1-rmse:0.818701
# [113]	validation_0-rmse:0.815886	validation_1-rmse:0.818234
# [114]	validation_0-rmse:0.815742	validation_1-rmse:0.818092
# [115]	validation_0-rmse:0.815608	validation_1-rmse:0.81796
# [116]	validation_0-rmse:0.815358	validation_1-rmse:0.817725
# [117]	validation_0-rmse:0.815043	validation_1-rmse:0.81741
# [118]	validation_0-rmse:0.814678	validation_1-rmse:0.81701
# [119]	validation_0-rmse:0.814536	validation_1-rmse:0.81686
# [120]	validation_0-rmse:0.814461	validation_1-rmse:0.816773
# [121]	validation_0-rmse:0.814149	validation_1-rmse:0.816458
# [122]	validation_0-rmse:0.814032	validation_1-rmse:0.816346
# [123]	validation_0-rmse:0.813754	validation_1-rmse:0.816081
# [124]	validation_0-rmse:0.813395	validation_1-rmse:0.815731
# [125]	validation_0-rmse:0.813187	validation_1-rmse:0.815525
# [126]	validation_0-rmse:0.813091	validation_1-rmse:0.815423
# [127]	validation_0-rmse:0.81239	validation_1-rmse:0.814698
# [128]	validation_0-rmse:0.81231	validation_1-rmse:0.814626
# [129]	validation_0-rmse:0.812194	validation_1-rmse:0.814508
# [130]	validation_0-rmse:0.812131	validation_1-rmse:0.814446
# [131]	validation_0-rmse:0.811932	validation_1-rmse:0.814268
# [132]	validation_0-rmse:0.811667	validation_1-rmse:0.814003
# [133]	validation_0-rmse:0.811561	validation_1-rmse:0.813912
# [134]	validation_0-rmse:0.811381	validation_1-rmse:0.813748
# [135]	validation_0-rmse:0.811018	validation_1-rmse:0.81339
# [136]	validation_0-rmse:0.810914	validation_1-rmse:0.813277
# [137]	validation_0-rmse:0.810764	validation_1-rmse:0.813151
# [138]	validation_0-rmse:0.810615	validation_1-rmse:0.812984
# [139]	validation_0-rmse:0.81027	validation_1-rmse:0.812659
# [140]	validation_0-rmse:0.810183	validation_1-rmse:0.81257
# [141]	validation_0-rmse:0.810008	validation_1-rmse:0.812367
# [142]	validation_0-rmse:0.809838	validation_1-rmse:0.812198
# [143]	validation_0-rmse:0.809795	validation_1-rmse:0.812152
# [144]	validation_0-rmse:0.809494	validation_1-rmse:0.811835
# [145]	validation_0-rmse:0.80933	validation_1-rmse:0.811647
# [146]	validation_0-rmse:0.809107	validation_1-rmse:0.811429
# [147]	validation_0-rmse:0.808934	validation_1-rmse:0.811251
# [148]	validation_0-rmse:0.808834	validation_1-rmse:0.811143
# [149]	validation_0-rmse:0.8087	validation_1-rmse:0.811008
# [150]	validation_0-rmse:0.808579	validation_1-rmse:0.810871
# [151]	validation_0-rmse:0.807913	validation_1-rmse:0.810238
# [152]	validation_0-rmse:0.807634	validation_1-rmse:0.809973
# [153]	validation_0-rmse:0.807434	validation_1-rmse:0.80978
# [154]	validation_0-rmse:0.807237	validation_1-rmse:0.809589
# [155]	validation_0-rmse:0.80704	validation_1-rmse:0.809399
# [156]	validation_0-rmse:0.806931	validation_1-rmse:0.809309
# [157]	validation_0-rmse:0.806854	validation_1-rmse:0.809228
# [158]	validation_0-rmse:0.806767	validation_1-rmse:0.809152
# [159]	validation_0-rmse:0.806672	validation_1-rmse:0.80906
# [160]	validation_0-rmse:0.806532	validation_1-rmse:0.808923
# [161]	validation_0-rmse:0.806348	validation_1-rmse:0.808756
# [162]	validation_0-rmse:0.806294	validation_1-rmse:0.808707
# [163]	validation_0-rmse:0.80612	validation_1-rmse:0.808545
# [164]	validation_0-rmse:0.806037	validation_1-rmse:0.808487
# [165]	validation_0-rmse:0.805802	validation_1-rmse:0.80827
# [166]	validation_0-rmse:0.805551	validation_1-rmse:0.808026
# [167]	validation_0-rmse:0.805466	validation_1-rmse:0.807939
# [168]	validation_0-rmse:0.80537	validation_1-rmse:0.80783
# [169]	validation_0-rmse:0.805271	validation_1-rmse:0.80773
# [170]	validation_0-rmse:0.805018	validation_1-rmse:0.807493
# [171]	validation_0-rmse:0.804956	validation_1-rmse:0.807431
# [172]	validation_0-rmse:0.804493	validation_1-rmse:0.806994
# [173]	validation_0-rmse:0.80439	validation_1-rmse:0.806874
# [174]	validation_0-rmse:0.804287	validation_1-rmse:0.806774
# [175]	validation_0-rmse:0.803976	validation_1-rmse:0.806482
# [176]	validation_0-rmse:0.803722	validation_1-rmse:0.806226
# [177]	validation_0-rmse:0.803612	validation_1-rmse:0.806096
# [178]	validation_0-rmse:0.803576	validation_1-rmse:0.806049
# [179]	validation_0-rmse:0.803452	validation_1-rmse:0.805919
# [180]	validation_0-rmse:0.803348	validation_1-rmse:0.805806
# [181]	validation_0-rmse:0.803297	validation_1-rmse:0.805755
# [182]	validation_0-rmse:0.803215	validation_1-rmse:0.80568
# [183]	validation_0-rmse:0.803159	validation_1-rmse:0.805622
# [184]	validation_0-rmse:0.803096	validation_1-rmse:0.805562
# [185]	validation_0-rmse:0.803012	validation_1-rmse:0.805467
# [186]	validation_0-rmse:0.802959	validation_1-rmse:0.805413
# [187]	validation_0-rmse:0.802736	validation_1-rmse:0.805204
# [188]	validation_0-rmse:0.802488	validation_1-rmse:0.804948
# [189]	validation_0-rmse:0.802418	validation_1-rmse:0.804874
# [190]	validation_0-rmse:0.802349	validation_1-rmse:0.804797
# [191]	validation_0-rmse:0.80199	validation_1-rmse:0.804509
# [192]	validation_0-rmse:0.801908	validation_1-rmse:0.804441
# [193]	validation_0-rmse:0.801804	validation_1-rmse:0.804349
# [194]	validation_0-rmse:0.80166	validation_1-rmse:0.804177
# [195]	validation_0-rmse:0.801515	validation_1-rmse:0.804035
# [196]	validation_0-rmse:0.80145	validation_1-rmse:0.803969
# [197]	validation_0-rmse:0.801309	validation_1-rmse:0.80383
# [198]	validation_0-rmse:0.801156	validation_1-rmse:0.803677
# [199]	validation_0-rmse:0.800886	validation_1-rmse:0.803385
# [200]	validation_0-rmse:0.800613	validation_1-rmse:0.803107
# [201]	validation_0-rmse:0.80049	validation_1-rmse:0.802977
# [202]	validation_0-rmse:0.800444	validation_1-rmse:0.80293
# [203]	validation_0-rmse:0.800416	validation_1-rmse:0.802891
# [204]	validation_0-rmse:0.800332	validation_1-rmse:0.802809
# [205]	validation_0-rmse:0.800236	validation_1-rmse:0.802683
# [206]	validation_0-rmse:0.800145	validation_1-rmse:0.802577
# [207]	validation_0-rmse:0.80009	validation_1-rmse:0.802513
# [208]	validation_0-rmse:0.799998	validation_1-rmse:0.802408
# [209]	validation_0-rmse:0.799901	validation_1-rmse:0.802317
# [210]	validation_0-rmse:0.799864	validation_1-rmse:0.802287
# [211]	validation_0-rmse:0.799617	validation_1-rmse:0.802038
# [212]	validation_0-rmse:0.79955	validation_1-rmse:0.801957
# [213]	validation_0-rmse:0.799487	validation_1-rmse:0.8019
# [214]	validation_0-rmse:0.799394	validation_1-rmse:0.801795
# [215]	validation_0-rmse:0.799187	validation_1-rmse:0.801632
# [216]	validation_0-rmse:0.799125	validation_1-rmse:0.801574
# [217]	validation_0-rmse:0.798975	validation_1-rmse:0.801415
# [218]	validation_0-rmse:0.798854	validation_1-rmse:0.801286
# [219]	validation_0-rmse:0.798787	validation_1-rmse:0.801241
# [220]	validation_0-rmse:0.798603	validation_1-rmse:0.801044
# [221]	validation_0-rmse:0.798508	validation_1-rmse:0.800954
# [222]	validation_0-rmse:0.798443	validation_1-rmse:0.800882
# [223]	validation_0-rmse:0.79839	validation_1-rmse:0.800827
# [224]	validation_0-rmse:0.798263	validation_1-rmse:0.800714
# [225]	validation_0-rmse:0.798103	validation_1-rmse:0.800553
# [226]	validation_0-rmse:0.798029	validation_1-rmse:0.800472
# [227]	validation_0-rmse:0.796961	validation_1-rmse:0.799527
# [228]	validation_0-rmse:0.796842	validation_1-rmse:0.799406
# [229]	validation_0-rmse:0.796619	validation_1-rmse:0.799209
# [230]	validation_0-rmse:0.796579	validation_1-rmse:0.799171
# [231]	validation_0-rmse:0.796366	validation_1-rmse:0.798937
# [232]	validation_0-rmse:0.796307	validation_1-rmse:0.79889
# [233]	validation_0-rmse:0.7962	validation_1-rmse:0.798778
# [234]	validation_0-rmse:0.796109	validation_1-rmse:0.798691
# [235]	validation_0-rmse:0.795826	validation_1-rmse:0.798408
# [236]	validation_0-rmse:0.795791	validation_1-rmse:0.798367
# [237]	validation_0-rmse:0.79554	validation_1-rmse:0.798146
# [238]	validation_0-rmse:0.795455	validation_1-rmse:0.798048
# [239]	validation_0-rmse:0.795393	validation_1-rmse:0.797977
# [240]	validation_0-rmse:0.795304	validation_1-rmse:0.797881
# [241]	validation_0-rmse:0.795235	validation_1-rmse:0.797815
# [242]	validation_0-rmse:0.795166	validation_1-rmse:0.797758
# [243]	validation_0-rmse:0.79491	validation_1-rmse:0.797538
# [244]	validation_0-rmse:0.794186	validation_1-rmse:0.796892
# [245]	validation_0-rmse:0.794103	validation_1-rmse:0.796801
# [246]	validation_0-rmse:0.794023	validation_1-rmse:0.796716
# [247]	validation_0-rmse:0.793926	validation_1-rmse:0.796638
# [248]	validation_0-rmse:0.793798	validation_1-rmse:0.796501
# [249]	validation_0-rmse:0.793756	validation_1-rmse:0.796457
# [250]	validation_0-rmse:0.793666	validation_1-rmse:0.796381
# [251]	validation_0-rmse:0.793611	validation_1-rmse:0.796333
# [252]	validation_0-rmse:0.793443	validation_1-rmse:0.796176
# [253]	validation_0-rmse:0.793327	validation_1-rmse:0.796071
# [254]	validation_0-rmse:0.793269	validation_1-rmse:0.79601
# [255]	validation_0-rmse:0.793202	validation_1-rmse:0.795951
# [256]	validation_0-rmse:0.793148	validation_1-rmse:0.795893
# [257]	validation_0-rmse:0.792587	validation_1-rmse:0.795377
# [258]	validation_0-rmse:0.792543	validation_1-rmse:0.79533
# [259]	validation_0-rmse:0.792492	validation_1-rmse:0.795272
# [260]	validation_0-rmse:0.792408	validation_1-rmse:0.795172
# [261]	validation_0-rmse:0.792206	validation_1-rmse:0.79498
# [262]	validation_0-rmse:0.792119	validation_1-rmse:0.794883
# [263]	validation_0-rmse:0.792074	validation_1-rmse:0.794846
# [264]	validation_0-rmse:0.792015	validation_1-rmse:0.794789
# [265]	validation_0-rmse:0.791938	validation_1-rmse:0.794706
# [266]	validation_0-rmse:0.791809	validation_1-rmse:0.794574
# [267]	validation_0-rmse:0.791728	validation_1-rmse:0.794492
# [268]	validation_0-rmse:0.791609	validation_1-rmse:0.79438
# [269]	validation_0-rmse:0.791529	validation_1-rmse:0.794295
# [270]	validation_0-rmse:0.791483	validation_1-rmse:0.794242
# [271]	validation_0-rmse:0.79145	validation_1-rmse:0.7942
# [272]	validation_0-rmse:0.791377	validation_1-rmse:0.794117
# [273]	validation_0-rmse:0.791276	validation_1-rmse:0.794005
# [274]	validation_0-rmse:0.791237	validation_1-rmse:0.793965
# [275]	validation_0-rmse:0.791176	validation_1-rmse:0.793899
# [276]	validation_0-rmse:0.790971	validation_1-rmse:0.793703
# [277]	validation_0-rmse:0.790715	validation_1-rmse:0.79343
# [278]	validation_0-rmse:0.790672	validation_1-rmse:0.793377
# [279]	validation_0-rmse:0.7906	validation_1-rmse:0.793301
# [280]	validation_0-rmse:0.790542	validation_1-rmse:0.793241
# [281]	validation_0-rmse:0.790424	validation_1-rmse:0.793138
# [282]	validation_0-rmse:0.790381	validation_1-rmse:0.793088
# [283]	validation_0-rmse:0.790338	validation_1-rmse:0.79305
# [284]	validation_0-rmse:0.790181	validation_1-rmse:0.792886
# [285]	validation_0-rmse:0.790054	validation_1-rmse:0.792757
# [286]	validation_0-rmse:0.789996	validation_1-rmse:0.792707
# [287]	validation_0-rmse:0.789953	validation_1-rmse:0.792663
# [288]	validation_0-rmse:0.789898	validation_1-rmse:0.792602
# [289]	validation_0-rmse:0.789847	validation_1-rmse:0.792559
# [290]	validation_0-rmse:0.789676	validation_1-rmse:0.792408
# [291]	validation_0-rmse:0.789557	validation_1-rmse:0.792299
# [292]	validation_0-rmse:0.789495	validation_1-rmse:0.792266
# [293]	validation_0-rmse:0.789045	validation_1-rmse:0.791814
# [294]	validation_0-rmse:0.788925	validation_1-rmse:0.791705
# [295]	validation_0-rmse:0.788797	validation_1-rmse:0.791601
# [296]	validation_0-rmse:0.788717	validation_1-rmse:0.791512
# [297]	validation_0-rmse:0.788686	validation_1-rmse:0.791481
# [298]	validation_0-rmse:0.788643	validation_1-rmse:0.791444
# [299]	validation_0-rmse:0.788497	validation_1-rmse:0.791313
# [300]	validation_0-rmse:0.788409	validation_1-rmse:0.791227
# [301]	validation_0-rmse:0.788304	validation_1-rmse:0.7911
# [302]	validation_0-rmse:0.788214	validation_1-rmse:0.791005
# [303]	validation_0-rmse:0.788161	validation_1-rmse:0.790943
# [304]	validation_0-rmse:0.788083	validation_1-rmse:0.790875
# [305]	validation_0-rmse:0.787879	validation_1-rmse:0.790673
# [306]	validation_0-rmse:0.78778	validation_1-rmse:0.790551
# [307]	validation_0-rmse:0.787718	validation_1-rmse:0.790476
# [308]	validation_0-rmse:0.787489	validation_1-rmse:0.79025
# [309]	validation_0-rmse:0.787451	validation_1-rmse:0.790207
# [310]	validation_0-rmse:0.787326	validation_1-rmse:0.790072
# [311]	validation_0-rmse:0.787143	validation_1-rmse:0.789893
# [312]	validation_0-rmse:0.787069	validation_1-rmse:0.789811
# [313]	validation_0-rmse:0.786999	validation_1-rmse:0.789737
# [314]	validation_0-rmse:0.786929	validation_1-rmse:0.78966
# [315]	validation_0-rmse:0.78657	validation_1-rmse:0.789338
# [316]	validation_0-rmse:0.786497	validation_1-rmse:0.789268
# [317]	validation_0-rmse:0.78641	validation_1-rmse:0.789177
# [318]	validation_0-rmse:0.786348	validation_1-rmse:0.789113
# [319]	validation_0-rmse:0.78631	validation_1-rmse:0.789091
# [320]	validation_0-rmse:0.786237	validation_1-rmse:0.789019
# [321]	validation_0-rmse:0.7862	validation_1-rmse:0.788986
# [322]	validation_0-rmse:0.786088	validation_1-rmse:0.788878
# [323]	validation_0-rmse:0.786022	validation_1-rmse:0.788811
# [324]	validation_0-rmse:0.785812	validation_1-rmse:0.78861
# [325]	validation_0-rmse:0.785784	validation_1-rmse:0.788581
# [326]	validation_0-rmse:0.785734	validation_1-rmse:0.788534
# [327]	validation_0-rmse:0.785689	validation_1-rmse:0.788487
# [328]	validation_0-rmse:0.785621	validation_1-rmse:0.788403
# [329]	validation_0-rmse:0.785552	validation_1-rmse:0.788334
# [330]	validation_0-rmse:0.785511	validation_1-rmse:0.788286
# [331]	validation_0-rmse:0.785309	validation_1-rmse:0.788116
# [332]	validation_0-rmse:0.785259	validation_1-rmse:0.788068
# [333]	validation_0-rmse:0.785156	validation_1-rmse:0.787965
# [334]	validation_0-rmse:0.785039	validation_1-rmse:0.787845
# [335]	validation_0-rmse:0.785002	validation_1-rmse:0.787807
# [336]	validation_0-rmse:0.784943	validation_1-rmse:0.787745
# [337]	validation_0-rmse:0.784907	validation_1-rmse:0.787705
# [338]	validation_0-rmse:0.784828	validation_1-rmse:0.787624
# [339]	validation_0-rmse:0.784791	validation_1-rmse:0.787603
# [340]	validation_0-rmse:0.784756	validation_1-rmse:0.787562
# [341]	validation_0-rmse:0.784727	validation_1-rmse:0.787539
# [342]	validation_0-rmse:0.784675	validation_1-rmse:0.787494
# [343]	validation_0-rmse:0.784629	validation_1-rmse:0.787451
# [344]	validation_0-rmse:0.784608	validation_1-rmse:0.787429
# [345]	validation_0-rmse:0.784532	validation_1-rmse:0.787339
# [346]	validation_0-rmse:0.784475	validation_1-rmse:0.787287
# [347]	validation_0-rmse:0.784426	validation_1-rmse:0.787243
# [348]	validation_0-rmse:0.784368	validation_1-rmse:0.787174
# [349]	validation_0-rmse:0.784311	validation_1-rmse:0.787109
# [350]	validation_0-rmse:0.784256	validation_1-rmse:0.787064
# [351]	validation_0-rmse:0.784205	validation_1-rmse:0.787007
# [352]	validation_0-rmse:0.784103	validation_1-rmse:0.7869
# [353]	validation_0-rmse:0.784037	validation_1-rmse:0.786832
# [354]	validation_0-rmse:0.783996	validation_1-rmse:0.786788
# [355]	validation_0-rmse:0.783782	validation_1-rmse:0.786547
# [356]	validation_0-rmse:0.783693	validation_1-rmse:0.78646
# [357]	validation_0-rmse:0.783639	validation_1-rmse:0.786412
# [358]	validation_0-rmse:0.783459	validation_1-rmse:0.786243
# [359]	validation_0-rmse:0.783358	validation_1-rmse:0.786145
# [360]	validation_0-rmse:0.783309	validation_1-rmse:0.7861
# [361]	validation_0-rmse:0.783286	validation_1-rmse:0.78608
# [362]	validation_0-rmse:0.783235	validation_1-rmse:0.786034
# [363]	validation_0-rmse:0.783198	validation_1-rmse:0.785986
# [364]	validation_0-rmse:0.783116	validation_1-rmse:0.785909
# [365]	validation_0-rmse:0.783071	validation_1-rmse:0.785868
# [366]	validation_0-rmse:0.783039	validation_1-rmse:0.785835
# [367]	validation_0-rmse:0.783002	validation_1-rmse:0.785795
# [368]	validation_0-rmse:0.782876	validation_1-rmse:0.785681
# [369]	validation_0-rmse:0.782816	validation_1-rmse:0.785618
# [370]	validation_0-rmse:0.782734	validation_1-rmse:0.785536
# [371]	validation_0-rmse:0.782696	validation_1-rmse:0.785503
# [372]	validation_0-rmse:0.782658	validation_1-rmse:0.785457
# [373]	validation_0-rmse:0.782613	validation_1-rmse:0.785409
# [374]	validation_0-rmse:0.782578	validation_1-rmse:0.785376
# [375]	validation_0-rmse:0.782544	validation_1-rmse:0.785326
# [376]	validation_0-rmse:0.78252	validation_1-rmse:0.785301
# [377]	validation_0-rmse:0.782343	validation_1-rmse:0.7851
# [378]	validation_0-rmse:0.782296	validation_1-rmse:0.785056
# [379]	validation_0-rmse:0.782268	validation_1-rmse:0.785031
# [380]	validation_0-rmse:0.782231	validation_1-rmse:0.784983
# [381]	validation_0-rmse:0.782202	validation_1-rmse:0.784947
# [382]	validation_0-rmse:0.782172	validation_1-rmse:0.784918
# [383]	validation_0-rmse:0.782153	validation_1-rmse:0.784887
# [384]	validation_0-rmse:0.781964	validation_1-rmse:0.784745
# [385]	validation_0-rmse:0.781861	validation_1-rmse:0.784636
# [386]	validation_0-rmse:0.781805	validation_1-rmse:0.784576
# [387]	validation_0-rmse:0.781776	validation_1-rmse:0.784546
# [388]	validation_0-rmse:0.781727	validation_1-rmse:0.784495
# [389]	validation_0-rmse:0.781681	validation_1-rmse:0.784456
# [390]	validation_0-rmse:0.781636	validation_1-rmse:0.784424
# [391]	validation_0-rmse:0.7816	validation_1-rmse:0.784395
# [392]	validation_0-rmse:0.781555	validation_1-rmse:0.784338
# [393]	validation_0-rmse:0.781512	validation_1-rmse:0.784292
# [394]	validation_0-rmse:0.781365	validation_1-rmse:0.784145
# [395]	validation_0-rmse:0.781298	validation_1-rmse:0.784084
# [396]	validation_0-rmse:0.781249	validation_1-rmse:0.784044
# [397]	validation_0-rmse:0.781215	validation_1-rmse:0.784028
# [398]	validation_0-rmse:0.781186	validation_1-rmse:0.783999
# [399]	validation_0-rmse:0.781147	validation_1-rmse:0.783956
# [400]	validation_0-rmse:0.781087	validation_1-rmse:0.783885
# [401]	validation_0-rmse:0.781011	validation_1-rmse:0.783822
# [402]	validation_0-rmse:0.78099	validation_1-rmse:0.783804
# [403]	validation_0-rmse:0.780945	validation_1-rmse:0.783761
# [404]	validation_0-rmse:0.78087	validation_1-rmse:0.783681
# [405]	validation_0-rmse:0.7808	validation_1-rmse:0.783608
# [406]	validation_0-rmse:0.780776	validation_1-rmse:0.783581
# [407]	validation_0-rmse:0.780747	validation_1-rmse:0.78356
# [408]	validation_0-rmse:0.780699	validation_1-rmse:0.783511
# [409]	validation_0-rmse:0.780654	validation_1-rmse:0.783468
# [410]	validation_0-rmse:0.7806	validation_1-rmse:0.78342
# [411]	validation_0-rmse:0.780522	validation_1-rmse:0.783346
# [412]	validation_0-rmse:0.780451	validation_1-rmse:0.783291
# [413]	validation_0-rmse:0.780413	validation_1-rmse:0.783253
# [414]	validation_0-rmse:0.780382	validation_1-rmse:0.783238
# [415]	validation_0-rmse:0.780348	validation_1-rmse:0.783213
# [416]	validation_0-rmse:0.780301	validation_1-rmse:0.783154
# [417]	validation_0-rmse:0.780262	validation_1-rmse:0.783117
# [418]	validation_0-rmse:0.780208	validation_1-rmse:0.783069
# [419]	validation_0-rmse:0.780155	validation_1-rmse:0.783006
# [420]	validation_0-rmse:0.780031	validation_1-rmse:0.782866
# [421]	validation_0-rmse:0.779998	validation_1-rmse:0.782836
# [422]	validation_0-rmse:0.779926	validation_1-rmse:0.782758
# [423]	validation_0-rmse:0.779792	validation_1-rmse:0.78262
# [424]	validation_0-rmse:0.779742	validation_1-rmse:0.782567
# [425]	validation_0-rmse:0.779713	validation_1-rmse:0.782535
# [426]	validation_0-rmse:0.779651	validation_1-rmse:0.782483
# [427]	validation_0-rmse:0.779622	validation_1-rmse:0.78245
# [428]	validation_0-rmse:0.779601	validation_1-rmse:0.782431
# [429]	validation_0-rmse:0.779563	validation_1-rmse:0.782395
# [430]	validation_0-rmse:0.779515	validation_1-rmse:0.782348
# [431]	validation_0-rmse:0.779464	validation_1-rmse:0.782304
# [432]	validation_0-rmse:0.779422	validation_1-rmse:0.782262
# [433]	validation_0-rmse:0.779355	validation_1-rmse:0.782199
# [434]	validation_0-rmse:0.779325	validation_1-rmse:0.782167
# [435]	validation_0-rmse:0.779268	validation_1-rmse:0.782103
# [436]	validation_0-rmse:0.779227	validation_1-rmse:0.782054
# [437]	validation_0-rmse:0.779193	validation_1-rmse:0.782013
# [438]	validation_0-rmse:0.779124	validation_1-rmse:0.781942
# [439]	validation_0-rmse:0.779092	validation_1-rmse:0.781918
# [440]	validation_0-rmse:0.779069	validation_1-rmse:0.781891
# [441]	validation_0-rmse:0.779041	validation_1-rmse:0.781868
# [442]	validation_0-rmse:0.778917	validation_1-rmse:0.781739
# [443]	validation_0-rmse:0.778896	validation_1-rmse:0.781719
# [444]	validation_0-rmse:0.77887	validation_1-rmse:0.781684
# [445]	validation_0-rmse:0.778835	validation_1-rmse:0.781639
# [446]	validation_0-rmse:0.778775	validation_1-rmse:0.781577
# [447]	validation_0-rmse:0.778723	validation_1-rmse:0.781528
# [448]	validation_0-rmse:0.778628	validation_1-rmse:0.781439
# [449]	validation_0-rmse:0.778582	validation_1-rmse:0.781397
# [450]	validation_0-rmse:0.778559	validation_1-rmse:0.781386
# [451]	validation_0-rmse:0.778438	validation_1-rmse:0.781265
# [452]	validation_0-rmse:0.778346	validation_1-rmse:0.781179
# [453]	validation_0-rmse:0.778297	validation_1-rmse:0.781127
# [454]	validation_0-rmse:0.778247	validation_1-rmse:0.781067
# [455]	validation_0-rmse:0.778225	validation_1-rmse:0.781035
# [456]	validation_0-rmse:0.778125	validation_1-rmse:0.780929
# [457]	validation_0-rmse:0.778084	validation_1-rmse:0.780884
# [458]	validation_0-rmse:0.778014	validation_1-rmse:0.780812
# [459]	validation_0-rmse:0.777994	validation_1-rmse:0.78079
# [460]	validation_0-rmse:0.77785	validation_1-rmse:0.780646
# [461]	validation_0-rmse:0.777798	validation_1-rmse:0.780591
# [462]	validation_0-rmse:0.777613	validation_1-rmse:0.780412
# [463]	validation_0-rmse:0.777531	validation_1-rmse:0.780305
# [464]	validation_0-rmse:0.777509	validation_1-rmse:0.780284
# [465]	validation_0-rmse:0.777465	validation_1-rmse:0.78024
# [466]	validation_0-rmse:0.777447	validation_1-rmse:0.780218
# [467]	validation_0-rmse:0.777361	validation_1-rmse:0.780137
# [468]	validation_0-rmse:0.777239	validation_1-rmse:0.780015
# [469]	validation_0-rmse:0.777182	validation_1-rmse:0.77996
# [470]	validation_0-rmse:0.777119	validation_1-rmse:0.779867
# [471]	validation_0-rmse:0.777054	validation_1-rmse:0.779808
# [472]	validation_0-rmse:0.777024	validation_1-rmse:0.77978
# [473]	validation_0-rmse:0.776904	validation_1-rmse:0.779647
# [474]	validation_0-rmse:0.776875	validation_1-rmse:0.779624
# [475]	validation_0-rmse:0.776754	validation_1-rmse:0.779486
# [476]	validation_0-rmse:0.776694	validation_1-rmse:0.779418
# [477]	validation_0-rmse:0.776578	validation_1-rmse:0.779309
# [478]	validation_0-rmse:0.776441	validation_1-rmse:0.779182
# [479]	validation_0-rmse:0.776405	validation_1-rmse:0.779142
# [480]	validation_0-rmse:0.776348	validation_1-rmse:0.779077
# [481]	validation_0-rmse:0.776278	validation_1-rmse:0.779002
# [482]	validation_0-rmse:0.776227	validation_1-rmse:0.778952
# [483]	validation_0-rmse:0.776102	validation_1-rmse:0.77881
# [484]	validation_0-rmse:0.776072	validation_1-rmse:0.778802
# [485]	validation_0-rmse:0.776052	validation_1-rmse:0.778774
# [486]	validation_0-rmse:0.776007	validation_1-rmse:0.77873
# [487]	validation_0-rmse:0.775973	validation_1-rmse:0.778677
# [488]	validation_0-rmse:0.775927	validation_1-rmse:0.778633
# [489]	validation_0-rmse:0.775872	validation_1-rmse:0.778563
# [490]	validation_0-rmse:0.775811	validation_1-rmse:0.778506
# [491]	validation_0-rmse:0.775794	validation_1-rmse:0.778481
# [492]	validation_0-rmse:0.775758	validation_1-rmse:0.77844
# [493]	validation_0-rmse:0.775689	validation_1-rmse:0.778372
# [494]	validation_0-rmse:0.77565	validation_1-rmse:0.778343
# [495]	validation_0-rmse:0.775619	validation_1-rmse:0.778307
# [496]	validation_0-rmse:0.775571	validation_1-rmse:0.778265
# [497]	validation_0-rmse:0.775536	validation_1-rmse:0.778236
# [498]	validation_0-rmse:0.775515	validation_1-rmse:0.778216
# [499]	validation_0-rmse:0.775463	validation_1-rmse:0.778164
# [500]	validation_0-rmse:0.775435	validation_1-rmse:0.778128
# [501]	validation_0-rmse:0.775394	validation_1-rmse:0.778095
# [502]	validation_0-rmse:0.775319	validation_1-rmse:0.778029
# [503]	validation_0-rmse:0.775291	validation_1-rmse:0.778007
# [504]	validation_0-rmse:0.775239	validation_1-rmse:0.777946
# [505]	validation_0-rmse:0.775147	validation_1-rmse:0.777858
# [506]	validation_0-rmse:0.775081	validation_1-rmse:0.777781
# [507]	validation_0-rmse:0.775016	validation_1-rmse:0.777717
# [508]	validation_0-rmse:0.774992	validation_1-rmse:0.777677
# [509]	validation_0-rmse:0.774969	validation_1-rmse:0.77765
# [510]	validation_0-rmse:0.774926	validation_1-rmse:0.777611
# [511]	validation_0-rmse:0.774902	validation_1-rmse:0.777591
# [512]	validation_0-rmse:0.774867	validation_1-rmse:0.777549
# [513]	validation_0-rmse:0.774809	validation_1-rmse:0.777499
# [514]	validation_0-rmse:0.774788	validation_1-rmse:0.777477
# [515]	validation_0-rmse:0.774728	validation_1-rmse:0.777425
# [516]	validation_0-rmse:0.774695	validation_1-rmse:0.777391
# [517]	validation_0-rmse:0.774667	validation_1-rmse:0.777364
# [518]	validation_0-rmse:0.774548	validation_1-rmse:0.777265
# [519]	validation_0-rmse:0.774508	validation_1-rmse:0.777223
# [520]	validation_0-rmse:0.774475	validation_1-rmse:0.777191
# [521]	validation_0-rmse:0.774318	validation_1-rmse:0.777039
# [522]	validation_0-rmse:0.774193	validation_1-rmse:0.776897
# [523]	validation_0-rmse:0.774101	validation_1-rmse:0.77682
# [524]	validation_0-rmse:0.774082	validation_1-rmse:0.77681
# [525]	validation_0-rmse:0.774054	validation_1-rmse:0.776783
# [526]	validation_0-rmse:0.773948	validation_1-rmse:0.776676
# [527]	validation_0-rmse:0.773913	validation_1-rmse:0.776638
# [528]	validation_0-rmse:0.773629	validation_1-rmse:0.776356
# [529]	validation_0-rmse:0.773455	validation_1-rmse:0.776178
# [530]	validation_0-rmse:0.773407	validation_1-rmse:0.776133
# [531]	validation_0-rmse:0.773366	validation_1-rmse:0.776101
# [532]	validation_0-rmse:0.773311	validation_1-rmse:0.776047
# [533]	validation_0-rmse:0.773262	validation_1-rmse:0.775998
# [534]	validation_0-rmse:0.773077	validation_1-rmse:0.775834
# [535]	validation_0-rmse:0.773045	validation_1-rmse:0.775804
# [536]	validation_0-rmse:0.773013	validation_1-rmse:0.775782
# [537]	validation_0-rmse:0.772987	validation_1-rmse:0.775755
# [538]	validation_0-rmse:0.772924	validation_1-rmse:0.77569
# [539]	validation_0-rmse:0.77282	validation_1-rmse:0.775591
# [540]	validation_0-rmse:0.772771	validation_1-rmse:0.775558
# [541]	validation_0-rmse:0.772631	validation_1-rmse:0.775445
# [542]	validation_0-rmse:0.772494	validation_1-rmse:0.775291
# [543]	validation_0-rmse:0.772472	validation_1-rmse:0.77527
# [544]	validation_0-rmse:0.772335	validation_1-rmse:0.77514
# [545]	validation_0-rmse:0.772298	validation_1-rmse:0.775107
# [546]	validation_0-rmse:0.772258	validation_1-rmse:0.775061
# [547]	validation_0-rmse:0.772208	validation_1-rmse:0.775005
# [548]	validation_0-rmse:0.772163	validation_1-rmse:0.774958
# [549]	validation_0-rmse:0.772141	validation_1-rmse:0.774942
# [550]	validation_0-rmse:0.772101	validation_1-rmse:0.774906
# [551]	validation_0-rmse:0.772082	validation_1-rmse:0.774886
# [552]	validation_0-rmse:0.772042	validation_1-rmse:0.774846
# [553]	validation_0-rmse:0.772013	validation_1-rmse:0.77482
# [554]	validation_0-rmse:0.771987	validation_1-rmse:0.774803
# [555]	validation_0-rmse:0.771967	validation_1-rmse:0.774775
# [556]	validation_0-rmse:0.771905	validation_1-rmse:0.774716
# [557]	validation_0-rmse:0.771882	validation_1-rmse:0.774687
# [558]	validation_0-rmse:0.771856	validation_1-rmse:0.774657
# [559]	validation_0-rmse:0.771831	validation_1-rmse:0.774624
# [560]	validation_0-rmse:0.771801	validation_1-rmse:0.774603
# [561]	validation_0-rmse:0.771768	validation_1-rmse:0.774572
# [562]	validation_0-rmse:0.77174	validation_1-rmse:0.774546
# [563]	validation_0-rmse:0.771723	validation_1-rmse:0.774526
# [564]	validation_0-rmse:0.771615	validation_1-rmse:0.77443
# [565]	validation_0-rmse:0.771567	validation_1-rmse:0.774382
# [566]	validation_0-rmse:0.77155	validation_1-rmse:0.774362
# [567]	validation_0-rmse:0.771511	validation_1-rmse:0.774323
# [568]	validation_0-rmse:0.771486	validation_1-rmse:0.774298
# [569]	validation_0-rmse:0.771455	validation_1-rmse:0.774259
# [570]	validation_0-rmse:0.771412	validation_1-rmse:0.77423
# [571]	validation_0-rmse:0.771349	validation_1-rmse:0.774163
# [572]	validation_0-rmse:0.771302	validation_1-rmse:0.774103
# [573]	validation_0-rmse:0.771266	validation_1-rmse:0.774067
# [574]	validation_0-rmse:0.771105	validation_1-rmse:0.773924
# [575]	validation_0-rmse:0.771064	validation_1-rmse:0.773885
# [576]	validation_0-rmse:0.77102	validation_1-rmse:0.773839
# [577]	validation_0-rmse:0.77098	validation_1-rmse:0.773797
# [578]	validation_0-rmse:0.770937	validation_1-rmse:0.773764
# [579]	validation_0-rmse:0.770903	validation_1-rmse:0.773725
# [580]	validation_0-rmse:0.770871	validation_1-rmse:0.773696
# [581]	validation_0-rmse:0.770841	validation_1-rmse:0.773667
# [582]	validation_0-rmse:0.770745	validation_1-rmse:0.77357
# [583]	validation_0-rmse:0.7707	validation_1-rmse:0.773525
# [584]	validation_0-rmse:0.770666	validation_1-rmse:0.773474
# [585]	validation_0-rmse:0.770643	validation_1-rmse:0.773457
# [586]	validation_0-rmse:0.770622	validation_1-rmse:0.773433
# [587]	validation_0-rmse:0.770537	validation_1-rmse:0.773345
# [588]	validation_0-rmse:0.770493	validation_1-rmse:0.773304
# [589]	validation_0-rmse:0.770434	validation_1-rmse:0.773252
# [590]	validation_0-rmse:0.770389	validation_1-rmse:0.773196
# [591]	validation_0-rmse:0.770365	validation_1-rmse:0.77317
# [592]	validation_0-rmse:0.770321	validation_1-rmse:0.773129
# [593]	validation_0-rmse:0.770287	validation_1-rmse:0.77311
# [594]	validation_0-rmse:0.770271	validation_1-rmse:0.773095
# [595]	validation_0-rmse:0.770223	validation_1-rmse:0.773039
# [596]	validation_0-rmse:0.770184	validation_1-rmse:0.772986
# [597]	validation_0-rmse:0.770139	validation_1-rmse:0.772943
# [598]	validation_0-rmse:0.770093	validation_1-rmse:0.772895
# [599]	validation_0-rmse:0.770062	validation_1-rmse:0.772867
# [600]	validation_0-rmse:0.770029	validation_1-rmse:0.772836
# [601]	validation_0-rmse:0.770008	validation_1-rmse:0.772809
# [602]	validation_0-rmse:0.769962	validation_1-rmse:0.772768
# [603]	validation_0-rmse:0.769928	validation_1-rmse:0.772726
# [604]	validation_0-rmse:0.769891	validation_1-rmse:0.772699
# [605]	validation_0-rmse:0.769775	validation_1-rmse:0.772569
# [606]	validation_0-rmse:0.769743	validation_1-rmse:0.772529
# [607]	validation_0-rmse:0.769699	validation_1-rmse:0.772481
# [608]	validation_0-rmse:0.769598	validation_1-rmse:0.772383
# [609]	validation_0-rmse:0.769579	validation_1-rmse:0.772356
# [610]	validation_0-rmse:0.769531	validation_1-rmse:0.7723
# [611]	validation_0-rmse:0.769511	validation_1-rmse:0.772288
# [612]	validation_0-rmse:0.769493	validation_1-rmse:0.77227
# [613]	validation_0-rmse:0.769453	validation_1-rmse:0.772231
# [614]	validation_0-rmse:0.769435	validation_1-rmse:0.772221
# [615]	validation_0-rmse:0.769333	validation_1-rmse:0.772113
# [616]	validation_0-rmse:0.769302	validation_1-rmse:0.77208
# [617]	validation_0-rmse:0.769267	validation_1-rmse:0.77204
# [618]	validation_0-rmse:0.769236	validation_1-rmse:0.772009
# [619]	validation_0-rmse:0.769214	validation_1-rmse:0.771986
# [620]	validation_0-rmse:0.769172	validation_1-rmse:0.771939
# [621]	validation_0-rmse:0.769149	validation_1-rmse:0.771914
# [622]	validation_0-rmse:0.769123	validation_1-rmse:0.771893
# [623]	validation_0-rmse:0.769092	validation_1-rmse:0.771873
# [624]	validation_0-rmse:0.769072	validation_1-rmse:0.771854
# [625]	validation_0-rmse:0.769043	validation_1-rmse:0.77182
# [626]	validation_0-rmse:0.76898	validation_1-rmse:0.771756
# [627]	validation_0-rmse:0.768945	validation_1-rmse:0.771725
# [628]	validation_0-rmse:0.768914	validation_1-rmse:0.771689
# [629]	validation_0-rmse:0.768881	validation_1-rmse:0.77167
# [630]	validation_0-rmse:0.76884	validation_1-rmse:0.771622
# [631]	validation_0-rmse:0.768794	validation_1-rmse:0.771569
# [632]	validation_0-rmse:0.768774	validation_1-rmse:0.771557
# [633]	validation_0-rmse:0.768738	validation_1-rmse:0.771521
# [634]	validation_0-rmse:0.768705	validation_1-rmse:0.771484
# [635]	validation_0-rmse:0.768671	validation_1-rmse:0.771443
# [636]	validation_0-rmse:0.768631	validation_1-rmse:0.771404
# [637]	validation_0-rmse:0.768605	validation_1-rmse:0.77137
# [638]	validation_0-rmse:0.768579	validation_1-rmse:0.771339
# [639]	validation_0-rmse:0.768558	validation_1-rmse:0.771319
# [640]	validation_0-rmse:0.76854	validation_1-rmse:0.771306
# [641]	validation_0-rmse:0.768508	validation_1-rmse:0.77127
# [642]	validation_0-rmse:0.768447	validation_1-rmse:0.771206
# [643]	validation_0-rmse:0.768412	validation_1-rmse:0.771163
# [644]	validation_0-rmse:0.768393	validation_1-rmse:0.77114
# [645]	validation_0-rmse:0.76837	validation_1-rmse:0.771113
# [646]	validation_0-rmse:0.768328	validation_1-rmse:0.771067
# [647]	validation_0-rmse:0.768198	validation_1-rmse:0.770933
# [648]	validation_0-rmse:0.768156	validation_1-rmse:0.770899
# [649]	validation_0-rmse:0.768108	validation_1-rmse:0.770862
# [650]	validation_0-rmse:0.768094	validation_1-rmse:0.77085
# [651]	validation_0-rmse:0.768006	validation_1-rmse:0.770769
# [652]	validation_0-rmse:0.767979	validation_1-rmse:0.770741
# [653]	validation_0-rmse:0.767962	validation_1-rmse:0.77072
# [654]	validation_0-rmse:0.767932	validation_1-rmse:0.770691
# [655]	validation_0-rmse:0.767914	validation_1-rmse:0.770659
# [656]	validation_0-rmse:0.767702	validation_1-rmse:0.770478
# [657]	validation_0-rmse:0.767684	validation_1-rmse:0.77046
# [658]	validation_0-rmse:0.767633	validation_1-rmse:0.770407
# [659]	validation_0-rmse:0.767581	validation_1-rmse:0.770358
# [660]	validation_0-rmse:0.767557	validation_1-rmse:0.770334
# [661]	validation_0-rmse:0.767484	validation_1-rmse:0.770248
# [662]	validation_0-rmse:0.767466	validation_1-rmse:0.770229
# [663]	validation_0-rmse:0.767412	validation_1-rmse:0.770173
# [664]	validation_0-rmse:0.767391	validation_1-rmse:0.770148
# [665]	validation_0-rmse:0.767361	validation_1-rmse:0.770115
# [666]	validation_0-rmse:0.767325	validation_1-rmse:0.77008
# [667]	validation_0-rmse:0.767315	validation_1-rmse:0.770069
# [668]	validation_0-rmse:0.767267	validation_1-rmse:0.77001
# [669]	validation_0-rmse:0.767227	validation_1-rmse:0.769956
# [670]	validation_0-rmse:0.767208	validation_1-rmse:0.769932
# [671]	validation_0-rmse:0.767018	validation_1-rmse:0.76975
# [672]	validation_0-rmse:0.766981	validation_1-rmse:0.76971
# [673]	validation_0-rmse:0.766928	validation_1-rmse:0.769658
# [674]	validation_0-rmse:0.766901	validation_1-rmse:0.769626
# [675]	validation_0-rmse:0.766849	validation_1-rmse:0.769577
# [676]	validation_0-rmse:0.766774	validation_1-rmse:0.76952
# [677]	validation_0-rmse:0.766729	validation_1-rmse:0.769468
# [678]	validation_0-rmse:0.766676	validation_1-rmse:0.769429
# [679]	validation_0-rmse:0.766653	validation_1-rmse:0.769389
# [680]	validation_0-rmse:0.766627	validation_1-rmse:0.769362
# [681]	validation_0-rmse:0.766598	validation_1-rmse:0.769327
# [682]	validation_0-rmse:0.766456	validation_1-rmse:0.769181
# [683]	validation_0-rmse:0.766436	validation_1-rmse:0.769172
# [684]	validation_0-rmse:0.766424	validation_1-rmse:0.769156
# [685]	validation_0-rmse:0.766396	validation_1-rmse:0.76912
# [686]	validation_0-rmse:0.76635	validation_1-rmse:0.769078
# [687]	validation_0-rmse:0.766319	validation_1-rmse:0.769042
# [688]	validation_0-rmse:0.766297	validation_1-rmse:0.76902
# [689]	validation_0-rmse:0.766269	validation_1-rmse:0.768992
# [690]	validation_0-rmse:0.76625	validation_1-rmse:0.768969
# [691]	validation_0-rmse:0.766219	validation_1-rmse:0.768941
# [692]	validation_0-rmse:0.766195	validation_1-rmse:0.768914
# [693]	validation_0-rmse:0.766142	validation_1-rmse:0.768854
# [694]	validation_0-rmse:0.76608	validation_1-rmse:0.768803
# [695]	validation_0-rmse:0.766061	validation_1-rmse:0.768781
# [696]	validation_0-rmse:0.766038	validation_1-rmse:0.768759
# [697]	validation_0-rmse:0.766015	validation_1-rmse:0.768731
# [698]	validation_0-rmse:0.765934	validation_1-rmse:0.768648
# [699]	validation_0-rmse:0.765901	validation_1-rmse:0.768615
# [700]	validation_0-rmse:0.76587	validation_1-rmse:0.768579
# [701]	validation_0-rmse:0.765817	validation_1-rmse:0.768531
# [702]	validation_0-rmse:0.765805	validation_1-rmse:0.768519
# [703]	validation_0-rmse:0.76578	validation_1-rmse:0.768495
# [704]	validation_0-rmse:0.765741	validation_1-rmse:0.76845
# [705]	validation_0-rmse:0.765708	validation_1-rmse:0.768425
# [706]	validation_0-rmse:0.765682	validation_1-rmse:0.768387
# [707]	validation_0-rmse:0.765661	validation_1-rmse:0.768362
# [708]	validation_0-rmse:0.765626	validation_1-rmse:0.768326
# [709]	validation_0-rmse:0.765591	validation_1-rmse:0.768293
# [710]	validation_0-rmse:0.765554	validation_1-rmse:0.768243
# [711]	validation_0-rmse:0.765527	validation_1-rmse:0.768208
# [712]	validation_0-rmse:0.76549	validation_1-rmse:0.76818
# [713]	validation_0-rmse:0.765471	validation_1-rmse:0.768161
# [714]	validation_0-rmse:0.765451	validation_1-rmse:0.768147
# [715]	validation_0-rmse:0.765383	validation_1-rmse:0.768078
# [716]	validation_0-rmse:0.765307	validation_1-rmse:0.768008
# [717]	validation_0-rmse:0.765274	validation_1-rmse:0.767979
# [718]	validation_0-rmse:0.765197	validation_1-rmse:0.767898
# [719]	validation_0-rmse:0.76518	validation_1-rmse:0.767884
# [720]	validation_0-rmse:0.765131	validation_1-rmse:0.767841
# [721]	validation_0-rmse:0.765108	validation_1-rmse:0.767814
# [722]	validation_0-rmse:0.765088	validation_1-rmse:0.767796
# [723]	validation_0-rmse:0.765057	validation_1-rmse:0.767755
# [724]	validation_0-rmse:0.765006	validation_1-rmse:0.767703
# [725]	validation_0-rmse:0.764982	validation_1-rmse:0.767685
# [726]	validation_0-rmse:0.764964	validation_1-rmse:0.767659
# [727]	validation_0-rmse:0.764904	validation_1-rmse:0.767595
# [728]	validation_0-rmse:0.764871	validation_1-rmse:0.76756
# [729]	validation_0-rmse:0.764812	validation_1-rmse:0.767497
# [730]	validation_0-rmse:0.764785	validation_1-rmse:0.767461
# [731]	validation_0-rmse:0.764758	validation_1-rmse:0.76744
# [732]	validation_0-rmse:0.764673	validation_1-rmse:0.767359
# [733]	validation_0-rmse:0.764626	validation_1-rmse:0.767308
# [734]	validation_0-rmse:0.764592	validation_1-rmse:0.767279
# [735]	validation_0-rmse:0.764569	validation_1-rmse:0.767245
# [736]	validation_0-rmse:0.764548	validation_1-rmse:0.767226
# [737]	validation_0-rmse:0.764443	validation_1-rmse:0.767111
# [738]	validation_0-rmse:0.764424	validation_1-rmse:0.767099
# [739]	validation_0-rmse:0.764408	validation_1-rmse:0.767081
# [740]	validation_0-rmse:0.764375	validation_1-rmse:0.767058
# [741]	validation_0-rmse:0.764335	validation_1-rmse:0.767027
# [742]	validation_0-rmse:0.764302	validation_1-rmse:0.767
# [743]	validation_0-rmse:0.764285	validation_1-rmse:0.766992
# [744]	validation_0-rmse:0.764262	validation_1-rmse:0.766973
# [745]	validation_0-rmse:0.764239	validation_1-rmse:0.766944
# [746]	validation_0-rmse:0.7642	validation_1-rmse:0.766901
# [747]	validation_0-rmse:0.764132	validation_1-rmse:0.766835
# [748]	validation_0-rmse:0.764099	validation_1-rmse:0.7668
# [749]	validation_0-rmse:0.764079	validation_1-rmse:0.766782
# [750]	validation_0-rmse:0.764064	validation_1-rmse:0.76676
# [751]	validation_0-rmse:0.763999	validation_1-rmse:0.766696
# [752]	validation_0-rmse:0.763967	validation_1-rmse:0.766665
# [753]	validation_0-rmse:0.763941	validation_1-rmse:0.766637
# [754]	validation_0-rmse:0.763871	validation_1-rmse:0.766576
# [755]	validation_0-rmse:0.763853	validation_1-rmse:0.76656
# [756]	validation_0-rmse:0.763834	validation_1-rmse:0.766538
# [757]	validation_0-rmse:0.763764	validation_1-rmse:0.766471
# [758]	validation_0-rmse:0.763741	validation_1-rmse:0.766445
# [759]	validation_0-rmse:0.763721	validation_1-rmse:0.76642
# [760]	validation_0-rmse:0.763699	validation_1-rmse:0.766402
# [761]	validation_0-rmse:0.763681	validation_1-rmse:0.766385
# [762]	validation_0-rmse:0.763657	validation_1-rmse:0.766353
# [763]	validation_0-rmse:0.763636	validation_1-rmse:0.766329
# [764]	validation_0-rmse:0.763621	validation_1-rmse:0.766312
# [765]	validation_0-rmse:0.763565	validation_1-rmse:0.76626
# [766]	validation_0-rmse:0.763521	validation_1-rmse:0.766208
# [767]	validation_0-rmse:0.763488	validation_1-rmse:0.766175
# [768]	validation_0-rmse:0.763463	validation_1-rmse:0.766153
# [769]	validation_0-rmse:0.763428	validation_1-rmse:0.766127
# [770]	validation_0-rmse:0.7634	validation_1-rmse:0.766092
# [771]	validation_0-rmse:0.763372	validation_1-rmse:0.766065
# [772]	validation_0-rmse:0.763352	validation_1-rmse:0.766034
# [773]	validation_0-rmse:0.763333	validation_1-rmse:0.766007
# [774]	validation_0-rmse:0.763309	validation_1-rmse:0.765977
# [775]	validation_0-rmse:0.763287	validation_1-rmse:0.765954
# [776]	validation_0-rmse:0.763251	validation_1-rmse:0.765915
# [777]	validation_0-rmse:0.763216	validation_1-rmse:0.765885
# [778]	validation_0-rmse:0.76317	validation_1-rmse:0.765838
# [779]	validation_0-rmse:0.763141	validation_1-rmse:0.765806
# [780]	validation_0-rmse:0.763091	validation_1-rmse:0.765756
# [781]	validation_0-rmse:0.762964	validation_1-rmse:0.765661
# [782]	validation_0-rmse:0.762943	validation_1-rmse:0.765643
# [783]	validation_0-rmse:0.762914	validation_1-rmse:0.765613
# [784]	validation_0-rmse:0.762763	validation_1-rmse:0.765473
# [785]	validation_0-rmse:0.762745	validation_1-rmse:0.765455
# [786]	validation_0-rmse:0.762703	validation_1-rmse:0.765419
# [787]	validation_0-rmse:0.762685	validation_1-rmse:0.765409
# [788]	validation_0-rmse:0.76267	validation_1-rmse:0.765395
# [789]	validation_0-rmse:0.762629	validation_1-rmse:0.765355
# [790]	validation_0-rmse:0.762608	validation_1-rmse:0.765336
# [791]	validation_0-rmse:0.762576	validation_1-rmse:0.7653
# [792]	validation_0-rmse:0.762554	validation_1-rmse:0.765269
# [793]	validation_0-rmse:0.76252	validation_1-rmse:0.765219
# [794]	validation_0-rmse:0.762489	validation_1-rmse:0.765182
# [795]	validation_0-rmse:0.762459	validation_1-rmse:0.765145
# [796]	validation_0-rmse:0.762435	validation_1-rmse:0.765122
# [797]	validation_0-rmse:0.762418	validation_1-rmse:0.765114
# [798]	validation_0-rmse:0.762387	validation_1-rmse:0.765076
# [799]	validation_0-rmse:0.762343	validation_1-rmse:0.765031
# [800]	validation_0-rmse:0.762329	validation_1-rmse:0.765021
# [801]	validation_0-rmse:0.762308	validation_1-rmse:0.765003
# [802]	validation_0-rmse:0.762173	validation_1-rmse:0.764844
# [803]	validation_0-rmse:0.762137	validation_1-rmse:0.764819
# [804]	validation_0-rmse:0.762057	validation_1-rmse:0.764747
# [805]	validation_0-rmse:0.762029	validation_1-rmse:0.764711
# [806]	validation_0-rmse:0.761922	validation_1-rmse:0.764601
# [807]	validation_0-rmse:0.76189	validation_1-rmse:0.764566
# [808]	validation_0-rmse:0.761866	validation_1-rmse:0.764535
# [809]	validation_0-rmse:0.761761	validation_1-rmse:0.764425
# [810]	validation_0-rmse:0.761719	validation_1-rmse:0.764382
# [811]	validation_0-rmse:0.761704	validation_1-rmse:0.764364
# [812]	validation_0-rmse:0.761689	validation_1-rmse:0.764351
# [813]	validation_0-rmse:0.761655	validation_1-rmse:0.764312
# [814]	validation_0-rmse:0.761638	validation_1-rmse:0.764295
# [815]	validation_0-rmse:0.761622	validation_1-rmse:0.764275
# [816]	validation_0-rmse:0.7616	validation_1-rmse:0.76424
# [817]	validation_0-rmse:0.761584	validation_1-rmse:0.764229
# [818]	validation_0-rmse:0.761537	validation_1-rmse:0.764178
# [819]	validation_0-rmse:0.761511	validation_1-rmse:0.764141
# [820]	validation_0-rmse:0.761473	validation_1-rmse:0.764101
# [821]	validation_0-rmse:0.761455	validation_1-rmse:0.764082
# [822]	validation_0-rmse:0.761439	validation_1-rmse:0.764074
# [823]	validation_0-rmse:0.761416	validation_1-rmse:0.76404
# [824]	validation_0-rmse:0.761365	validation_1-rmse:0.763996
# [825]	validation_0-rmse:0.761326	validation_1-rmse:0.763959
# [826]	validation_0-rmse:0.761313	validation_1-rmse:0.763949
# [827]	validation_0-rmse:0.761281	validation_1-rmse:0.763921
# [828]	validation_0-rmse:0.761254	validation_1-rmse:0.763892
# [829]	validation_0-rmse:0.76123	validation_1-rmse:0.76387
# [830]	validation_0-rmse:0.761203	validation_1-rmse:0.763852
# [831]	validation_0-rmse:0.76118	validation_1-rmse:0.763826
# [832]	validation_0-rmse:0.761156	validation_1-rmse:0.763799
# [833]	validation_0-rmse:0.761139	validation_1-rmse:0.763775
# [834]	validation_0-rmse:0.761114	validation_1-rmse:0.763749
# [835]	validation_0-rmse:0.76109	validation_1-rmse:0.763728
# [836]	validation_0-rmse:0.761018	validation_1-rmse:0.763636
# [837]	validation_0-rmse:0.760992	validation_1-rmse:0.763601
# [838]	validation_0-rmse:0.760921	validation_1-rmse:0.763519
# [839]	validation_0-rmse:0.76088	validation_1-rmse:0.763477
# [840]	validation_0-rmse:0.760857	validation_1-rmse:0.763441
# [841]	validation_0-rmse:0.760835	validation_1-rmse:0.763416
# [842]	validation_0-rmse:0.76076	validation_1-rmse:0.763327
# [843]	validation_0-rmse:0.760708	validation_1-rmse:0.763285
# [844]	validation_0-rmse:0.760684	validation_1-rmse:0.763259
# [845]	validation_0-rmse:0.760668	validation_1-rmse:0.763249
# [846]	validation_0-rmse:0.760652	validation_1-rmse:0.763223
# [847]	validation_0-rmse:0.76061	validation_1-rmse:0.763191
# [848]	validation_0-rmse:0.760594	validation_1-rmse:0.763174
# [849]	validation_0-rmse:0.760574	validation_1-rmse:0.763145
# [850]	validation_0-rmse:0.760547	validation_1-rmse:0.763126
# [851]	validation_0-rmse:0.760509	validation_1-rmse:0.76309
# [852]	validation_0-rmse:0.760483	validation_1-rmse:0.763071
# [853]	validation_0-rmse:0.760463	validation_1-rmse:0.763055
# [854]	validation_0-rmse:0.760442	validation_1-rmse:0.763028
# [855]	validation_0-rmse:0.760411	validation_1-rmse:0.763002
# [856]	validation_0-rmse:0.760376	validation_1-rmse:0.762968
# [857]	validation_0-rmse:0.760345	validation_1-rmse:0.762941
# [858]	validation_0-rmse:0.760315	validation_1-rmse:0.762922
# [859]	validation_0-rmse:0.760286	validation_1-rmse:0.762901
# [860]	validation_0-rmse:0.760231	validation_1-rmse:0.762832
# [861]	validation_0-rmse:0.760221	validation_1-rmse:0.762821
# [862]	validation_0-rmse:0.760201	validation_1-rmse:0.762795
# [863]	validation_0-rmse:0.76018	validation_1-rmse:0.762771
# [864]	validation_0-rmse:0.760157	validation_1-rmse:0.76274
# [865]	validation_0-rmse:0.760126	validation_1-rmse:0.762705
# [866]	validation_0-rmse:0.760103	validation_1-rmse:0.762684
# [867]	validation_0-rmse:0.760081	validation_1-rmse:0.762663
# [868]	validation_0-rmse:0.759836	validation_1-rmse:0.762399
# [869]	validation_0-rmse:0.759819	validation_1-rmse:0.762381
# [870]	validation_0-rmse:0.759796	validation_1-rmse:0.762351
# [871]	validation_0-rmse:0.759757	validation_1-rmse:0.762311
# [872]	validation_0-rmse:0.759731	validation_1-rmse:0.762283
# [873]	validation_0-rmse:0.759701	validation_1-rmse:0.762237
# [874]	validation_0-rmse:0.759688	validation_1-rmse:0.762218
# [875]	validation_0-rmse:0.759665	validation_1-rmse:0.762194
# [876]	validation_0-rmse:0.759637	validation_1-rmse:0.762173
# [877]	validation_0-rmse:0.759551	validation_1-rmse:0.762081
# [878]	validation_0-rmse:0.759519	validation_1-rmse:0.762052
# [879]	validation_0-rmse:0.759496	validation_1-rmse:0.762028
# [880]	validation_0-rmse:0.759481	validation_1-rmse:0.762022
# [881]	validation_0-rmse:0.759461	validation_1-rmse:0.762002
# [882]	validation_0-rmse:0.759434	validation_1-rmse:0.761974
# [883]	validation_0-rmse:0.759397	validation_1-rmse:0.761933
# [884]	validation_0-rmse:0.759384	validation_1-rmse:0.761914
# [885]	validation_0-rmse:0.759362	validation_1-rmse:0.761883
# [886]	validation_0-rmse:0.759338	validation_1-rmse:0.761857
# [887]	validation_0-rmse:0.759304	validation_1-rmse:0.761815
# [888]	validation_0-rmse:0.759276	validation_1-rmse:0.761795
# [889]	validation_0-rmse:0.759258	validation_1-rmse:0.761778
# [890]	validation_0-rmse:0.759233	validation_1-rmse:0.761755
# [891]	validation_0-rmse:0.75922	validation_1-rmse:0.761739
# [892]	validation_0-rmse:0.759181	validation_1-rmse:0.761696
# [893]	validation_0-rmse:0.759165	validation_1-rmse:0.761679
# [894]	validation_0-rmse:0.75914	validation_1-rmse:0.761659
# [895]	validation_0-rmse:0.759123	validation_1-rmse:0.761641
# [896]	validation_0-rmse:0.759037	validation_1-rmse:0.761551
# [897]	validation_0-rmse:0.758994	validation_1-rmse:0.761491
# [898]	validation_0-rmse:0.758966	validation_1-rmse:0.76146
# [899]	validation_0-rmse:0.758949	validation_1-rmse:0.76144
# [900]	validation_0-rmse:0.758929	validation_1-rmse:0.761419
# [901]	validation_0-rmse:0.758884	validation_1-rmse:0.761385
# [902]	validation_0-rmse:0.75885	validation_1-rmse:0.761353
# [903]	validation_0-rmse:0.758827	validation_1-rmse:0.761333
# [904]	validation_0-rmse:0.758816	validation_1-rmse:0.761324
# [905]	validation_0-rmse:0.758793	validation_1-rmse:0.761309
# [906]	validation_0-rmse:0.758781	validation_1-rmse:0.761306
# [907]	validation_0-rmse:0.758758	validation_1-rmse:0.761279
# [908]	validation_0-rmse:0.75869	validation_1-rmse:0.761204
# [909]	validation_0-rmse:0.758656	validation_1-rmse:0.761173
# [910]	validation_0-rmse:0.758639	validation_1-rmse:0.761151
# [911]	validation_0-rmse:0.758621	validation_1-rmse:0.761133
# [912]	validation_0-rmse:0.758604	validation_1-rmse:0.761115
# [913]	validation_0-rmse:0.758585	validation_1-rmse:0.76109
# [914]	validation_0-rmse:0.758555	validation_1-rmse:0.76106
# [915]	validation_0-rmse:0.758532	validation_1-rmse:0.761028
# [916]	validation_0-rmse:0.758515	validation_1-rmse:0.761016
# [917]	validation_0-rmse:0.758485	validation_1-rmse:0.760982
# [918]	validation_0-rmse:0.758441	validation_1-rmse:0.760944
# [919]	validation_0-rmse:0.758427	validation_1-rmse:0.760935
# [920]	validation_0-rmse:0.758391	validation_1-rmse:0.760892
# [921]	validation_0-rmse:0.758364	validation_1-rmse:0.760863
# [922]	validation_0-rmse:0.758349	validation_1-rmse:0.76085
# [923]	validation_0-rmse:0.75829	validation_1-rmse:0.76078
# [924]	validation_0-rmse:0.758276	validation_1-rmse:0.760767
# [925]	validation_0-rmse:0.758231	validation_1-rmse:0.760728
# [926]	validation_0-rmse:0.758208	validation_1-rmse:0.760702
# [927]	validation_0-rmse:0.758181	validation_1-rmse:0.760678
# [928]	validation_0-rmse:0.758168	validation_1-rmse:0.760665
# [929]	validation_0-rmse:0.758058	validation_1-rmse:0.76056
# [930]	validation_0-rmse:0.758037	validation_1-rmse:0.760543
# [931]	validation_0-rmse:0.757982	validation_1-rmse:0.760482
# [932]	validation_0-rmse:0.757969	validation_1-rmse:0.760476
# [933]	validation_0-rmse:0.757945	validation_1-rmse:0.760457
# [934]	validation_0-rmse:0.757932	validation_1-rmse:0.760441
# [935]	validation_0-rmse:0.7579	validation_1-rmse:0.760391
# [936]	validation_0-rmse:0.757863	validation_1-rmse:0.760359
# [937]	validation_0-rmse:0.757844	validation_1-rmse:0.760345
# [938]	validation_0-rmse:0.757823	validation_1-rmse:0.760323
# [939]	validation_0-rmse:0.757789	validation_1-rmse:0.760295
# [940]	validation_0-rmse:0.757756	validation_1-rmse:0.76025
# [941]	validation_0-rmse:0.75773	validation_1-rmse:0.760228
# [942]	validation_0-rmse:0.757683	validation_1-rmse:0.760185
# [943]	validation_0-rmse:0.757656	validation_1-rmse:0.760151
# [944]	validation_0-rmse:0.757633	validation_1-rmse:0.760132
# [945]	validation_0-rmse:0.757593	validation_1-rmse:0.76009
# [946]	validation_0-rmse:0.757567	validation_1-rmse:0.760067
# [947]	validation_0-rmse:0.757547	validation_1-rmse:0.760045
# [948]	validation_0-rmse:0.757511	validation_1-rmse:0.760018
# [949]	validation_0-rmse:0.757488	validation_1-rmse:0.759992
# [950]	validation_0-rmse:0.757473	validation_1-rmse:0.759973
# [951]	validation_0-rmse:0.757438	validation_1-rmse:0.759936
# [952]	validation_0-rmse:0.757408	validation_1-rmse:0.759909
# [953]	validation_0-rmse:0.757385	validation_1-rmse:0.759889
# [954]	validation_0-rmse:0.757374	validation_1-rmse:0.759887
# [955]	validation_0-rmse:0.757356	validation_1-rmse:0.759863
# [956]	validation_0-rmse:0.757331	validation_1-rmse:0.759837
# [957]	validation_0-rmse:0.757288	validation_1-rmse:0.759798
# [958]	validation_0-rmse:0.757253	validation_1-rmse:0.759758
# [959]	validation_0-rmse:0.757216	validation_1-rmse:0.759732
# [960]	validation_0-rmse:0.757072	validation_1-rmse:0.759599
# [961]	validation_0-rmse:0.757046	validation_1-rmse:0.759576
# [962]	validation_0-rmse:0.757003	validation_1-rmse:0.759528
# [963]	validation_0-rmse:0.756981	validation_1-rmse:0.759506
# [964]	validation_0-rmse:0.756952	validation_1-rmse:0.759473
# [965]	validation_0-rmse:0.756916	validation_1-rmse:0.75943
# [966]	validation_0-rmse:0.756901	validation_1-rmse:0.759414
# [967]	validation_0-rmse:0.756862	validation_1-rmse:0.759371
# [968]	validation_0-rmse:0.756833	validation_1-rmse:0.759353
# [969]	validation_0-rmse:0.756802	validation_1-rmse:0.759312
# [970]	validation_0-rmse:0.756777	validation_1-rmse:0.759283
# [971]	validation_0-rmse:0.756761	validation_1-rmse:0.75926
# [972]	validation_0-rmse:0.756733	validation_1-rmse:0.759226
# [973]	validation_0-rmse:0.75672	validation_1-rmse:0.759213
# [974]	validation_0-rmse:0.756688	validation_1-rmse:0.759189
# [975]	validation_0-rmse:0.756671	validation_1-rmse:0.759165
# [976]	validation_0-rmse:0.756657	validation_1-rmse:0.759152
# [977]	validation_0-rmse:0.756643	validation_1-rmse:0.759143
# [978]	validation_0-rmse:0.756606	validation_1-rmse:0.759104
# [979]	validation_0-rmse:0.756538	validation_1-rmse:0.759033
# [980]	validation_0-rmse:0.756518	validation_1-rmse:0.759005
# [981]	validation_0-rmse:0.756485	validation_1-rmse:0.758968
# [982]	validation_0-rmse:0.756454	validation_1-rmse:0.758938
# [983]	validation_0-rmse:0.75642	validation_1-rmse:0.758904
# [984]	validation_0-rmse:0.756397	validation_1-rmse:0.758883
# [985]	validation_0-rmse:0.756347	validation_1-rmse:0.75883
# [986]	validation_0-rmse:0.756332	validation_1-rmse:0.758815
# [987]	validation_0-rmse:0.756305	validation_1-rmse:0.758784
# [988]	validation_0-rmse:0.756281	validation_1-rmse:0.758761
# [989]	validation_0-rmse:0.756265	validation_1-rmse:0.758744
# [990]	validation_0-rmse:0.756228	validation_1-rmse:0.758713
# [991]	validation_0-rmse:0.756207	validation_1-rmse:0.758693
# [992]	validation_0-rmse:0.756125	validation_1-rmse:0.758621
# [993]	validation_0-rmse:0.756096	validation_1-rmse:0.758589
# [994]	validation_0-rmse:0.75607	validation_1-rmse:0.758555
# [995]	validation_0-rmse:0.756052	validation_1-rmse:0.758544
# [996]	validation_0-rmse:0.756029	validation_1-rmse:0.758517
# [997]	validation_0-rmse:0.756018	validation_1-rmse:0.758495
# [998]	validation_0-rmse:0.755933	validation_1-rmse:0.758408
# [999]	validation_0-rmse:0.755926	validation_1-rmse:0.758396
# CPU times: user 6h 40min 50s, sys: 3min 47s, total: 6h 44min 38s
# Wall time: 8h 36min 43s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=8, min_child_weight=300, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.8, verbosity=1)

# %% [markdown]
# Result of running the above on baseline set of predictors:
#
# [100]	validation_0-rmse:0.819027	validation_1-rmse:0.821394
# [999]	validation_0-rmse:0.755926	validation_1-rmse:0.758396
# CPU times: user 6h 40min 50s, sys: 3min 47s, total: 6h 44min 38s
# Wall time: 8h 36min 43s
#
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=8, min_child_weight=300, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.8, verbosity=1)

# %%
from tabulate import tabulate
headers = ["name", "score"]
values = sorted(zip(X_test.columns, xgmodel.feature_importances_), key=lambda x: x[1] * -1)
print(tabulate(values, headers, tablefmt="plain"))
# Out:
# name                                               score
# total_monthly_city_item_sales_lag_1           0.259705
# target_lag_1                                  0.224477
# total_monthly_shop_subcategory_sales_lag_1    0.052103
# target_lag_2                                  0.0351695
# total_monthly_item_sales_lag_1                0.0344082
# item_category_id                              0.0291885
# target_lag_3                                  0.0282539
# type_code                                     0.0249709
# total_monthly_shop_category_sales_lag_1       0.0227484
# total_monthly_sales_lag_1                     0.020068
# subtype_code                                  0.019753
# total_monthly_shop_sales_lag_12               0.0195617
# target_lag_6                                  0.0192548
# total_monthly_shop_sales_lag_1                0.016111
# total_monthly_item_sales_lag_2                0.0158148
# date_block_num                                0.0153869
# total_monthly_item_sales_lag_6                0.0152624
# total_monthly_item_sales_lag_3                0.0148048
# item_id                                       0.0129347
# total_monthly_shop_sales_lag_2                0.0128533
# total_monthly_shop_supercategory_sales_lag_1  0.0119389
# total_monthly_item_sales_lag_12               0.0114658
# shop_id                                       0.0114425
# total_monthly_shop_sales_lag_6                0.0109618
# total_monthly_supercategory_sales_lag_1       0.0102058
# total_monthly_subcategory_sales_lag_1         0.0097301
# total_monthly_category_sales_lag_1            0.00929085
# total_monthly_shop_sales_lag_3                0.00902824
# target_lag_12                                 0.0085216
# city_code                                     0.00817944
# total_monthly_city_sales_lag_1                0.00640465

# %%
# %%time
from xgboost import XGBRegressor

xgmodel2 = XGBRegressor(
    max_depth=8,
    n_estimators=100,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

xgmodel2.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, y_train), (X_test, y_test)], 
    verbose=True, 
    early_stopping_rounds = 10)
# Out:
# /usr/local/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:52:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:52:29] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	validation_0-rmse:1.13969	validation_1-rmse:1.16152
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.10131	validation_1-rmse:1.11249
# [2]	validation_0-rmse:1.07134	validation_1-rmse:1.0733
# [3]	validation_0-rmse:1.0282	validation_1-rmse:1.04446
# [4]	validation_0-rmse:1.00266	validation_1-rmse:1.02161
# [5]	validation_0-rmse:0.980696	validation_1-rmse:0.995302
# [6]	validation_0-rmse:0.963531	validation_1-rmse:0.976133
# [7]	validation_0-rmse:0.946256	validation_1-rmse:0.960218
# [8]	validation_0-rmse:0.932016	validation_1-rmse:0.947468
# [9]	validation_0-rmse:0.920972	validation_1-rmse:0.936503
# [10]	validation_0-rmse:0.912262	validation_1-rmse:0.926946
# [11]	validation_0-rmse:0.903827	validation_1-rmse:0.916295
# [12]	validation_0-rmse:0.896814	validation_1-rmse:0.908058
# [13]	validation_0-rmse:0.891176	validation_1-rmse:0.901402
# [14]	validation_0-rmse:0.885808	validation_1-rmse:0.895334
# [15]	validation_0-rmse:0.881887	validation_1-rmse:0.890774
# [16]	validation_0-rmse:0.878251	validation_1-rmse:0.886819
# [17]	validation_0-rmse:0.874828	validation_1-rmse:0.882977
# [18]	validation_0-rmse:0.871923	validation_1-rmse:0.879943
# [19]	validation_0-rmse:0.868667	validation_1-rmse:0.876506
# [20]	validation_0-rmse:0.866469	validation_1-rmse:0.874264
# [21]	validation_0-rmse:0.864285	validation_1-rmse:0.871954
# [22]	validation_0-rmse:0.861978	validation_1-rmse:0.869677
# [23]	validation_0-rmse:0.859725	validation_1-rmse:0.867361
# [24]	validation_0-rmse:0.858448	validation_1-rmse:0.866028
# [25]	validation_0-rmse:0.856958	validation_1-rmse:0.864462
# [26]	validation_0-rmse:0.855439	validation_1-rmse:0.863012
# [27]	validation_0-rmse:0.853949	validation_1-rmse:0.86156
# [28]	validation_0-rmse:0.852465	validation_1-rmse:0.860167
# [29]	validation_0-rmse:0.850543	validation_1-rmse:0.858171
# [30]	validation_0-rmse:0.849026	validation_1-rmse:0.856712
# [31]	validation_0-rmse:0.847751	validation_1-rmse:0.855417
# [32]	validation_0-rmse:0.84643	validation_1-rmse:0.854166
# [33]	validation_0-rmse:0.845717	validation_1-rmse:0.853512
# [34]	validation_0-rmse:0.844424	validation_1-rmse:0.852284
# [35]	validation_0-rmse:0.84319	validation_1-rmse:0.851065
# [36]	validation_0-rmse:0.842478	validation_1-rmse:0.850405
# [37]	validation_0-rmse:0.841075	validation_1-rmse:0.849031
# [38]	validation_0-rmse:0.839771	validation_1-rmse:0.84775
# [39]	validation_0-rmse:0.838898	validation_1-rmse:0.84694
# [40]	validation_0-rmse:0.83833	validation_1-rmse:0.846413
# [41]	validation_0-rmse:0.837409	validation_1-rmse:0.84558
# [42]	validation_0-rmse:0.836614	validation_1-rmse:0.844825
# [43]	validation_0-rmse:0.836117	validation_1-rmse:0.844307
# [44]	validation_0-rmse:0.835415	validation_1-rmse:0.843681
# [45]	validation_0-rmse:0.834366	validation_1-rmse:0.842722
# [46]	validation_0-rmse:0.833847	validation_1-rmse:0.842258
# [47]	validation_0-rmse:0.833444	validation_1-rmse:0.841936
# [48]	validation_0-rmse:0.832666	validation_1-rmse:0.841214
# [49]	validation_0-rmse:0.832054	validation_1-rmse:0.840654
# [50]	validation_0-rmse:0.831471	validation_1-rmse:0.840178
# [51]	validation_0-rmse:0.830536	validation_1-rmse:0.839324
# [52]	validation_0-rmse:0.829957	validation_1-rmse:0.838838
# [53]	validation_0-rmse:0.829183	validation_1-rmse:0.838102
# [54]	validation_0-rmse:0.82883	validation_1-rmse:0.837779
# [55]	validation_0-rmse:0.828285	validation_1-rmse:0.837297
# [56]	validation_0-rmse:0.827954	validation_1-rmse:0.836979
# [57]	validation_0-rmse:0.827378	validation_1-rmse:0.836463
# [58]	validation_0-rmse:0.826572	validation_1-rmse:0.835709
# [59]	validation_0-rmse:0.826217	validation_1-rmse:0.835453
# [60]	validation_0-rmse:0.825244	validation_1-rmse:0.834595
# [61]	validation_0-rmse:0.824891	validation_1-rmse:0.834266
# [62]	validation_0-rmse:0.824493	validation_1-rmse:0.83395
# [63]	validation_0-rmse:0.824117	validation_1-rmse:0.833652
# [64]	validation_0-rmse:0.823838	validation_1-rmse:0.83344
# [65]	validation_0-rmse:0.823395	validation_1-rmse:0.83306
# [66]	validation_0-rmse:0.823251	validation_1-rmse:0.83295
# [67]	validation_0-rmse:0.823013	validation_1-rmse:0.832786
# [68]	validation_0-rmse:0.822581	validation_1-rmse:0.832472
# [69]	validation_0-rmse:0.822336	validation_1-rmse:0.832297
# [70]	validation_0-rmse:0.821881	validation_1-rmse:0.831864
# [71]	validation_0-rmse:0.821685	validation_1-rmse:0.83173
# [72]	validation_0-rmse:0.821416	validation_1-rmse:0.831515
# [73]	validation_0-rmse:0.821058	validation_1-rmse:0.831239
# [74]	validation_0-rmse:0.820666	validation_1-rmse:0.830895
# [75]	validation_0-rmse:0.820333	validation_1-rmse:0.83065
# [76]	validation_0-rmse:0.820213	validation_1-rmse:0.830561
# [77]	validation_0-rmse:0.819837	validation_1-rmse:0.83023
# [78]	validation_0-rmse:0.819568	validation_1-rmse:0.830051
# [79]	validation_0-rmse:0.819248	validation_1-rmse:0.829785
# [80]	validation_0-rmse:0.818946	validation_1-rmse:0.8295
# [81]	validation_0-rmse:0.818745	validation_1-rmse:0.829359
# [82]	validation_0-rmse:0.818282	validation_1-rmse:0.828979
# [83]	validation_0-rmse:0.817937	validation_1-rmse:0.828682
# [84]	validation_0-rmse:0.817628	validation_1-rmse:0.828452
# [85]	validation_0-rmse:0.817507	validation_1-rmse:0.828355
# [86]	validation_0-rmse:0.817314	validation_1-rmse:0.828214
# [87]	validation_0-rmse:0.817201	validation_1-rmse:0.82814
# [88]	validation_0-rmse:0.81673	validation_1-rmse:0.827718
# [89]	validation_0-rmse:0.816345	validation_1-rmse:0.82736
# [90]	validation_0-rmse:0.815838	validation_1-rmse:0.826919
# [91]	validation_0-rmse:0.815624	validation_1-rmse:0.826754
# [92]	validation_0-rmse:0.815484	validation_1-rmse:0.826644
# [93]	validation_0-rmse:0.81516	validation_1-rmse:0.82637
# [94]	validation_0-rmse:0.814936	validation_1-rmse:0.826178
# [95]	validation_0-rmse:0.814773	validation_1-rmse:0.826081
# [96]	validation_0-rmse:0.81442	validation_1-rmse:0.825759
# [97]	validation_0-rmse:0.814122	validation_1-rmse:0.825482
# [98]	validation_0-rmse:0.813868	validation_1-rmse:0.82527
# [99]	validation_0-rmse:0.813741	validation_1-rmse:0.82519
# CPU times: user 1h 20min 58s, sys: 47.9 s, total: 1h 21min 46s
# Wall time: 11h 7s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=8, min_child_weight=300, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.8, verbosity=1)

# %%
headers = ["name", "score"]
values = sorted(zip(X_test.columns, xgmodel2.feature_importances_), key=lambda x: x[1] * -1)
print(tabulate(values, headers, tablefmt="plain"))
# Out:
# name                                               score
# target_lag_1                                  0.288597
# total_monthly_city_item_sales_lag_1           0.220565
# target_lag_2                                  0.0499196
# total_monthly_shop_subcategory_sales_lag_1    0.0427704
# target_lag_3                                  0.0355518
# total_monthly_item_sales_lag_1                0.0271202
# stock_lag3                                    0.0231447
# item_category_id                              0.0215563
# total_monthly_shop_sales_lag_12               0.0211006
# stock_lag2                                    0.0175127
# target_lag_6                                  0.0171282
# subtype_code                                  0.016695
# total_monthly_shop_category_sales_lag_1       0.0151175
# total_monthly_shop_supercategory_sales_lag_1  0.0129055
# total_monthly_shop_sales_lag_6                0.0125209
# total_monthly_item_sales_lag_12               0.0123925
# total_monthly_item_sales_lag_2                0.0119308
# total_monthly_shop_sales_lag_2                0.0118901
# total_monthly_sales_lag_1                     0.0116902
# total_monthly_shop_sales_lag_1                0.0115336
# total_monthly_item_sales_lag_6                0.0100948
# total_monthly_item_sales_lag_3                0.00992673
# total_monthly_shop_sales_lag_3                0.00924687
# date_block_num                                0.00876152
# item_id                                       0.00857334
# lag3                                          0.0074239
# target_lag_12                                 0.00729258
# stock_lag1                                    0.0064232
# total_monthly_supercategory_sales_lag_1       0.00587322
# total_monthly_subcategory_sales_lag_1         0.00550353
# lag2                                          0.0053777
# shop_id                                       0.005323
# total_monthly_category_sales_lag_1            0.00521803
# lag1                                          0.0047608
# total_monthly_city_sales_lag_1                0.00474094
# no_sales                                      0.00471191
# city_code                                     0.004645
# type_code                                     0.00446088

# %%
# combine
month_34 = all_data[all_data.date_block_num == 34].fillna(0)
month_34['item_cnt_month'] = xgmodel.predict(month_34[predictors])
test = pd.merge(test_df,month_34, on=["shop_id","item_id"]).fillna(0)

test = test.loc[:,['ID', 'item_cnt_month']]
test.set_index("ID", inplace=True)
test["item_cnt_month"] = test["item_cnt_month"] #.round().astype("int64") do not round up, you are screwing RSS

test[test.item_cnt_month>20] = 20
test.to_csv("basic_predictors_xgb.csv")

# %%
train = all_data[(all_data.date_block_num>11)&(all_data.date_block_num<34)].fillna(0)

X_train = train[train.date_block_num <  33][predictors]
X_valid = train[train.date_block_num == 33][predictors]
y_train = train[train.date_block_num <  33].target
y_valid = train[train.date_block_num == 33].target

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=64, max_features=6, n_jobs=6) #len(predictors)/2
model.fit(X_train, y_train)
#from joblib import dump, load
#dump(model,"model1.joblib")
# Out:
# CPU times: user 1h 13min 23s, sys: 58.8 s, total: 1h 14min 22s
# Wall time: 23min 11s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=6, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=64, n_jobs=6,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False)

# %%
from sklearn.metrics import mean_squared_error

ypred = model.predict(X_valid)
rmse = np.sqrt(mean_squared_error(y_valid, ypred))
print("RMSE good: %f" % (rmse))
print("Average good: {0}".format(np.mean(ypred)))
# Out:
# RMSE good: 0.943238
# Average good: 0.3053031265220093

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor
full_model = RandomForestRegressor(n_estimators=64, max_features=6, n_jobs=6)
full_model.fit(train[predictors], train.target)
# Out:
# CPU times: user 1h 6min 2s, sys: 58.1 s, total: 1h 7min
# Wall time: 18min 16s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=6, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=64, n_jobs=6,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False)

# %%
# combine
month_34 = all_data[all_data.date_block_num == 34].fillna(0)
month_34['item_cnt_month'] = full_model.predict(month_34[predictors])
test = pd.merge(test_df,month_34, on=["shop_id","item_id"]).fillna(0)

test = test.loc[:,['ID', 'item_cnt_month']]
test.set_index("ID", inplace=True)
test["item_cnt_month"] = test["item_cnt_month"] #.round().astype("int64") do not round up, you are screwing RSS

test[test.item_cnt_month>20] = 20
test.to_csv("few_more_predictors.csv")

## automatically set 0 for "bad" items
#test = pd.merge(test_df, month_34, how="left", on=["shop_id","item_id"]).fillna(0)
#
## zeroing out
#print(test[test.shop_id.isin(closed_shops)].shape)
#
#suppress = test.item_id.isin(items_never_sold).apply(lambda x: 0 if x else 1)
#test.item_cnt_month *= suppress
#
#test = test.loc[:,['ID', 'item_cnt_month']]
#test.set_index("ID", inplace=True)
#test["item_cnt_month"] = test["item_cnt_month"].round().astype("int64")
#
## clipping
#test[test.item_cnt_month>20] = 20
#
#test.to_csv("item_trends.csv")

# %%
# public score: 1.04069

# %%
# %macro -q __trends_combined 3-35

# %%
# %store __trends_combined
# Out:
# Stored '__trends_combined' (Macro)

# %% [markdown]
# ## Seasonal components
#
# First of all, it totally make sense to introduce some more surrogate variables:
# * month of the year (1-12)
# * cristmas sale (True/False)
# * sales 12 month ago
# * current trend

# %%
# identify shops and items with sales history of > 1 year (needed for seasonal component)

monthly.groupby(['shop_id']).agg({'date_block_num': [min,max]})
# Out:
#         date_block_num
#                    min max
# shop_id
# 0                    0   1
# 1                    0   1
# 2                    0  33
# 3                    0  33
# 4                    0  33
# 5                    1  33
# 6                    0  33
# 7                    0  33
# 8                    0   3
# 9                    9  33
# 10                   0  33
# 11                  25  25
# 12                   0  33
# 13                   0  19
# 14                   0  33
# 15                   0  33
# 16                   0  33
# 17                   5  24
# 18                   0  33
# 19                   0  33
# 20                  21  33
# 21                   0  33
# 22                   0  33
# 23                   0   3
# 24                   0  33
# 25                   0  33
# 26                   0  33
# 27                   0  32
# 28                   0  33
# 29                   0  28
# 30                   0  25
# 31                   0  33
# 32                   0   6
# 33                  19  27
# 34                  18  33
# 35                   0  33
# 36                  33  33
# 37                   0  33
# 38                   0  33
# 39                  14  33
# 40                  14  24
# 41                   0  33
# 42                   0  33
# 43                   0  24
# 44                   0  33
# 45                   0  33
# 46                   0  33
# 47                   0  33
# 48                  15  33
# 49                  11  33
# 50                   0  33
# 51                   0  32
# 52                   0  33
# 53                   0  33
# 54                   0  27
# 55                   4  33
# 56                   0  33
# 57                   2  33
# 58                   2  33
# 59                   0  33

# %%
# Create data frame associating data_block_num with date (January, 2013 is date_block_num==0)
timeline = pd.DataFrame({'begin_date': pd.date_range(start='2013-01-01',end='2015-11-01', freq='MS'),
                         'date_block_num': range(35)} )

timeline.tail()
# Out:
#    begin_date  date_block_num
# 30 2015-07-01              30
# 31 2015-08-01              31
# 32 2015-09-01              32
# 33 2015-10-01              33
# 34 2015-11-01              34

# %%
#Lags for mean encodings too!
